# %%
# !pip install diffusers["torch"] transformers accelerate
# !pip install git+https://github.com/huggingface/diffusers
# !pip install einops
# !pip install compel

# %%
# !unzip kvasir-seg.zip

# %%
import shutil, os, random
import numpy as np
from PIL import Image


def sample_set_kavasir(root_dir, target_dir, sample_size=50):
  if not os.path.isdir(root_dir):
    raise ValueError('invalid root_dir: {}'.format(root_dir))
  if os.path.isdir(target_dir):
    shutil.rmtree(target_dir)
  os.mkdir(target_dir)
  os.mkdir(os.path.join(target_dir, 'images'))
  os.mkdir(os.path.join(target_dir, 'segmentations'))

  image_dir = os.path.join(root_dir, 'images')
  mask_dir = os.path.join(root_dir, 'masks')
  image_dir_2 = os.path.join(target_dir, 'images')
  mask_dir_2 = os.path.join(target_dir, 'segmentations')
  file_list = os.listdir(image_dir)
  sample_list = random.sample(file_list, sample_size)
  for f in sample_list:
    source = os.path.join(image_dir, f)
    target = os.path.join(image_dir_2, f)
    shutil.copy(source, target)

    source = os.path.join(mask_dir, f)
    target = os.path.join(mask_dir_2, f)
    shutil.copy(source, target)


root_dir = 'Kvasir-SEG' # size 1000
target_dir = 'Kvasir-SEG-sample'
sample_size = 100 # samll: 30, large: 300

sample_set_kavasir(root_dir, target_dir, sample_size)
print('>>> sample size', len(os.listdir(os.path.join(target_dir, 'images'))))
# Out:
# >>> sample size 100

# %%
# import locale
# locale.getpreferredencoding = lambda: "UTF-8"
# !zip -r Kvasir-SEG-sample.zip Kvasir-SEG-sample
# from google.colab import files
# files.download("Kvasir-SEG-sample.zip")

import shutil
import os
shutil.rmtree('Kvasir-SEG')
os.rename('Kvasir-SEG-sample', 'Kvasir-SEG')

# %%
# !jar xvf buildings_vaihingen.zip

# %%
import shutil, os, random
import numpy as np
from PIL import Image

def transform(i):
  res = str(i)
  if len(res) < 3:
    prefix = "0" if len(res) == 2 else "00"
    res = prefix + res

  return res

def sample_set_vaihingen(root_dir, target_dir, sample_size=50):
  if not os.path.isdir(root_dir):
    raise ValueError('invalid root_dir: {}'.format(root_dir))
  if os.path.isdir(target_dir):
    shutil.rmtree(target_dir)
  os.mkdir(target_dir)
  os.mkdir(os.path.join(target_dir, 'images'))
  os.mkdir(os.path.join(target_dir, 'segmentations'))

  index_range = range(1, 169)
  sample_index = random.sample(index_range, sample_size)
  for idx in sample_index:
    i = transform(idx)
    img_name = "building_{}.tif".format(i)
    mask_name = "all_buildings_mask_{}.tif".format(i)
    img_path = os.path.join(root_dir, img_name)
    mask_path = os.path.join(root_dir, mask_name)

    img_path_2 = os.path.join(target_dir, 'images', '{}.tif'.format(i))
    mask_path_2 = os.path.join(target_dir, 'segmentations', '{}.tif'.format(i))
    shutil.copy(img_path, img_path_2)
    shutil.copy(mask_path, mask_path_2)

root_dir = 'buildings'
target_dir = 'Vaihingen-sample' # size 168
sample_size = 100 # small: 20, large: 150

sample_set_vaihingen(root_dir, target_dir, sample_size)
print('>>> sample size', len(os.listdir(os.path.join(target_dir, 'images'))))
# Out:
# >>> sample size 100

# %%
import shutil
import os
shutil.rmtree('buildings')
os.rename('Vaihingen-sample', 'Vaihingen')

# %%
import shutil, os, random
import numpy as np
from PIL import Image
from torchvision.datasets import VOCSegmentation

voc_data = VOCSegmentation('./', download=True)
print('>>> all size', len(voc_data))
VOC_label_map = {
  1:'aeroplane',
  2:'bicycle',
  3:'bird',
  4:'boat',
  5:'bottle',
  6:'bus',
  7:'car',
  8:'cat',
  9:'chair',
  10:'cow',
  11:'diningtable',
  12:'dog',
  13:'horse',
  14:'motorbike',
  15:'person',
  16:'pottedplant',
  17:'sheep',
  18:'sofa',
  19:'train',
  20:'tvmonitor'
}

def sample_set_voc(voc_data, target_dir, sample_size_per_class=5):
  if os.path.isdir(target_dir):
    shutil.rmtree(target_dir)
  os.mkdir(target_dir)
  os.mkdir(os.path.join(target_dir, 'images'))
  os.mkdir(os.path.join(target_dir, 'segmentations'))

  freq_map = {idx: sample_size_per_class for idx in VOC_label_map.keys()}
  count = 0

  # Single-class samples
  print(">>> singl-class sampels")
  for idx in range(len(voc_data)):
    if len(freq_map) == 0:
      break
    img, seg = voc_data[idx]
    seg_arr = np.asarray(seg)
    label = np.unique(seg_arr)
    if len(label) != 3:
      continue
    label = label[1]
    if not label in freq_map.keys():
      continue
    freq = freq_map[label]
    if freq == 1:
      del freq_map[label]
    else:
      freq_map[label] -= 1
    print('save 1 {} >>>'.format(idx))
    img.save(os.path.join(target_dir, 'images', '{}.png'.format(idx)))
    seg.save(os.path.join(target_dir, 'segmentations', '{}.png'.format(idx)))

  if len(freq_map) != 0:
    print(freq_map)
  selected_list = os.listdir(os.path.join(target_dir, 'images'))
  print(">>> multi-class sampels")
  for idx in range(len(voc_data)):
    if len(freq_map) == 0:
      break
    file_name = '{}.png'.format(idx)
    if file_name in selected_list:
      continue
    img, seg = voc_data[idx]
    seg_arr = np.asarray(seg)
    label = np.unique(seg_arr)
    save = False
    for l in label:
      if l in freq_map.keys():
        save = True
        freq = freq_map[l]
        if freq == 1:
          del freq_map[l]
        else:
          freq_map[l] -= 1
    if save:
      print('save 2 {} >>>'.format(idx))
      img.save(os.path.join(target_dir, 'images', file_name))
      seg.save(os.path.join(target_dir, 'segmentations', file_name))

  sample_size = len(os.listdir(os.path.join(target_dir, 'images')))
  target_sample_size = len(VOC_label_map.keys()) * sample_size_per_class
  print(sample_size, target_sample_size)
  selected_list = os.listdir(os.path.join(target_dir, 'images'))
  if sample_size < target_sample_size:
    print(">>> the num per class constraint is unachievable")
    count = target_sample_size - sample_size
    for idx in range(len(voc_data)):
      if count == 0:
        return
      file_name = '{}.png'.format(idx)
      if file_name in selected_list:
        continue
      print('save 3 {} >>>'.format(idx))
      img, seg = voc_data[idx]
      img.save(os.path.join(target_dir, 'images', file_name))
      seg.save(os.path.join(target_dir, 'segmentations', file_name))
      count -= 1


target_dir = 'VOC-sample'
sample_set_voc(voc_data, target_dir, sample_size_per_class=25)# size 1464
print('>>> sample size', len(os.listdir(os.path.join(target_dir, 'images'))))
# Out:
# Using downloaded and verified file: ./VOCtrainval_11-May-2012.tar
# Extracting ./VOCtrainval_11-May-2012.tar to ./
# >>> all size 1464
# >>> singl-class sampels
# save 1 1 >>>
# save 1 3 >>>
# save 1 4 >>>
# save 1 6 >>>
# save 1 7 >>>
# save 1 9 >>>
# save 1 10 >>>
# save 1 11 >>>
# save 1 17 >>>
# save 1 18 >>>
# save 1 20 >>>
# save 1 22 >>>
# save 1 23 >>>
# save 1 25 >>>
# save 1 26 >>>
# save 1 28 >>>
# save 1 30 >>>
# save 1 33 >>>
# save 1 36 >>>
# save 1 38 >>>
# save 1 39 >>>
# save 1 42 >>>
# save 1 43 >>>
# save 1 44 >>>
# save 1 46 >>>
# save 1 47 >>>
# save 1 49 >>>
# save 1 50 >>>
# save 1 52 >>>
# save 1 54 >>>
# save 1 56 >>>
# save 1 57 >>>
# save 1 60 >>>
# save 1 61 >>>
# save 1 63 >>>
# save 1 65 >>>
# save 1 66 >>>
# save 1 67 >>>
# save 1 68 >>>
# save 1 70 >>>
# save 1 73 >>>
# save 1 78 >>>
# save 1 82 >>>
# save 1 85 >>>
# save 1 87 >>>
# save 1 88 >>>
# save 1 89 >>>
# save 1 92 >>>
# save 1 93 >>>
# save 1 94 >>>
# save 1 96 >>>
# save 1 98 >>>
# save 1 99 >>>
# save 1 101 >>>
# save 1 103 >>>
# save 1 104 >>>
# save 1 105 >>>
# save 1 108 >>>
# save 1 111 >>>
# save 1 112 >>>
# save 1 113 >>>
# save 1 115 >>>
# save 1 116 >>>
# save 1 120 >>>
# save 1 123 >>>
# save 1 124 >>>
# save 1 130 >>>
# save 1 131 >>>
# save 1 135 >>>
# save 1 137 >>>
# save 1 138 >>>
# save 1 141 >>>
# save 1 145 >>>
# save 1 146 >>>
# save 1 147 >>>
# save 1 148 >>>
# save 1 149 >>>
# save 1 150 >>>
# save 1 154 >>>
# save 1 155 >>>
# save 1 156 >>>
# save 1 158 >>>
# save 1 161 >>>
# save 1 164 >>>
# save 1 165 >>>
# save 1 169 >>>
# save 1 173 >>>
# save 1 174 >>>
# save 1 175 >>>
# save 1 181 >>>
# save 1 182 >>>
# save 1 184 >>>
# save 1 185 >>>
# save 1 186 >>>
# save 1 187 >>>
# save 1 190 >>>
# save 1 200 >>>
# save 1 201 >>>
# save 1 204 >>>
# save 1 206 >>>
# save 1 208 >>>
# save 1 209 >>>
# save 1 210 >>>
# save 1 211 >>>
# save 1 216 >>>
# save 1 217 >>>
# save 1 218 >>>
# save 1 221 >>>
# save 1 227 >>>
# save 1 228 >>>
# save 1 230 >>>
# save 1 232 >>>
# save 1 234 >>>
# save 1 236 >>>
# save 1 237 >>>
# save 1 240 >>>
# save 1 241 >>>
# save 1 243 >>>
# save 1 244 >>>
# save 1 245 >>>
# save 1 249 >>>
# save 1 250 >>>
# save 1 252 >>>
# save 1 253 >>>
# save 1 256 >>>
# save 1 260 >>>
# save 1 261 >>>
# save 1 262 >>>
# save 1 263 >>>
# save 1 267 >>>
# save 1 271 >>>
# save 1 272 >>>
# save 1 274 >>>
# save 1 281 >>>
# save 1 282 >>>
# save 1 285 >>>
# save 1 286 >>>
# save 1 287 >>>
# save 1 290 >>>
# save 1 291 >>>
# save 1 292 >>>
# save 1 293 >>>
# save 1 294 >>>
# save 1 299 >>>
# save 1 300 >>>
# save 1 301 >>>
# save 1 304 >>>
# save 1 305 >>>
# save 1 306 >>>
# save 1 307 >>>
# save 1 311 >>>
# save 1 312 >>>
# save 1 313 >>>
# save 1 314 >>>
# save 1 315 >>>
# save 1 316 >>>
# save 1 317 >>>
# save 1 318 >>>
# save 1 319 >>>
# save 1 321 >>>
# save 1 322 >>>
# save 1 323 >>>
# save 1 324 >>>
# save 1 325 >>>
# save 1 326 >>>
# save 1 329 >>>
# save 1 330 >>>
# save 1 333 >>>
# save 1 334 >>>
# save 1 336 >>>
# save 1 337 >>>
# save 1 338 >>>
# save 1 339 >>>
# save 1 340 >>>
# save 1 341 >>>
# save 1 342 >>>
# save 1 343 >>>
# save 1 344 >>>
# save 1 345 >>>
# save 1 346 >>>
# save 1 347 >>>
# save 1 348 >>>
# save 1 350 >>>
# save 1 351 >>>
# save 1 352 >>>
# save 1 354 >>>
# save 1 358 >>>
# save 1 359 >>>
# save 1 361 >>>
# save 1 362 >>>
# save 1 363 >>>
# save 1 364 >>>
# save 1 366 >>>
# save 1 369 >>>
# save 1 370 >>>
# save 1 372 >>>
# save 1 375 >>>
# save 1 376 >>>
# save 1 377 >>>
# save 1 380 >>>
# save 1 382 >>>
# save 1 383 >>>
# save 1 386 >>>
# save 1 387 >>>
# save 1 392 >>>
# save 1 396 >>>
# save 1 402 >>>
# save 1 403 >>>
# save 1 407 >>>
# save 1 408 >>>
# save 1 409 >>>
# save 1 410 >>>
# save 1 412 >>>
# save 1 413 >>>
# save 1 414 >>>
# save 1 415 >>>
# save 1 417 >>>
# save 1 419 >>>
# save 1 422 >>>
# save 1 426 >>>
# save 1 432 >>>
# save 1 434 >>>
# save 1 435 >>>
# save 1 438 >>>
# save 1 440 >>>
# save 1 444 >>>
# save 1 445 >>>
# save 1 446 >>>
# save 1 450 >>>
# save 1 451 >>>
# save 1 453 >>>
# save 1 454 >>>
# save 1 455 >>>
# save 1 456 >>>
# save 1 457 >>>
# save 1 458 >>>
# save 1 460 >>>
# save 1 461 >>>
# save 1 467 >>>
# save 1 468 >>>
# save 1 471 >>>
# save 1 472 >>>
# save 1 475 >>>
# save 1 476 >>>
# save 1 477 >>>
# save 1 481 >>>
# save 1 483 >>>
# save 1 484 >>>
# save 1 485 >>>
# save 1 486 >>>
# save 1 488 >>>
# save 1 489 >>>
# save 1 492 >>>
# save 1 495 >>>
# save 1 502 >>>
# save 1 503 >>>
# save 1 505 >>>
# save 1 507 >>>
# save 1 508 >>>
# save 1 510 >>>
# save 1 512 >>>
# save 1 513 >>>
# save 1 517 >>>
# save 1 518 >>>
# save 1 520 >>>
# save 1 522 >>>
# save 1 523 >>>
# save 1 524 >>>
# save 1 525 >>>
# save 1 526 >>>
# save 1 528 >>>
# save 1 529 >>>
# save 1 531 >>>
# save 1 533 >>>
# save 1 534 >>>
# save 1 535 >>>
# save 1 537 >>>
# save 1 539 >>>
# save 1 540 >>>
# save 1 542 >>>
# save 1 544 >>>
# save 1 545 >>>
# save 1 547 >>>
# save 1 548 >>>
# save 1 549 >>>
# save 1 551 >>>
# save 1 554 >>>
# save 1 555 >>>
# save 1 556 >>>
# save 1 558 >>>
# save 1 559 >>>
# save 1 560 >>>
# save 1 561 >>>
# save 1 562 >>>
# save 1 564 >>>
# save 1 566 >>>
# save 1 567 >>>
# save 1 568 >>>
# save 1 569 >>>
# save 1 571 >>>
# save 1 573 >>>
# save 1 574 >>>
# save 1 576 >>>
# save 1 579 >>>
# save 1 581 >>>
# save 1 582 >>>
# save 1 585 >>>
# save 1 586 >>>
# save 1 590 >>>
# save 1 591 >>>
# save 1 592 >>>
# save 1 593 >>>
# save 1 594 >>>
# save 1 598 >>>
# save 1 601 >>>
# save 1 603 >>>
# save 1 608 >>>
# save 1 609 >>>
# save 1 614 >>>
# save 1 616 >>>
# save 1 617 >>>
# save 1 619 >>>
# save 1 621 >>>
# save 1 622 >>>
# save 1 624 >>>
# save 1 625 >>>
# save 1 627 >>>
# save 1 628 >>>
# save 1 631 >>>
# save 1 632 >>>
# save 1 637 >>>
# save 1 638 >>>
# save 1 639 >>>
# save 1 640 >>>
# save 1 642 >>>
# save 1 645 >>>
# save 1 646 >>>
# save 1 648 >>>
# save 1 649 >>>
# save 1 655 >>>
# save 1 657 >>>
# save 1 661 >>>
# save 1 665 >>>
# save 1 666 >>>
# save 1 667 >>>
# save 1 668 >>>
# save 1 673 >>>
# save 1 674 >>>
# save 1 680 >>>
# save 1 681 >>>
# save 1 682 >>>
# save 1 689 >>>
# save 1 690 >>>
# save 1 694 >>>
# save 1 695 >>>
# save 1 700 >>>
# save 1 701 >>>
# save 1 702 >>>
# save 1 703 >>>
# save 1 705 >>>
# save 1 708 >>>
# save 1 710 >>>
# save 1 713 >>>
# save 1 718 >>>
# save 1 720 >>>
# save 1 726 >>>
# save 1 730 >>>
# save 1 731 >>>
# save 1 732 >>>
# save 1 734 >>>
# save 1 737 >>>
# save 1 740 >>>
# save 1 742 >>>
# save 1 752 >>>
# save 1 754 >>>
# save 1 757 >>>
# save 1 758 >>>
# save 1 759 >>>
# save 1 764 >>>
# save 1 765 >>>
# save 1 766 >>>
# save 1 767 >>>
# save 1 777 >>>
# save 1 779 >>>
# save 1 784 >>>
# save 1 785 >>>
# save 1 788 >>>
# save 1 793 >>>
# save 1 797 >>>
# save 1 800 >>>
# save 1 805 >>>
# save 1 807 >>>
# save 1 810 >>>
# save 1 814 >>>
# save 1 819 >>>
# save 1 821 >>>
# save 1 823 >>>
# save 1 824 >>>
# save 1 826 >>>
# save 1 830 >>>
# save 1 831 >>>
# save 1 833 >>>
# save 1 835 >>>
# save 1 844 >>>
# save 1 849 >>>
# save 1 850 >>>
# save 1 851 >>>
# save 1 860 >>>
# save 1 864 >>>
# save 1 865 >>>
# save 1 867 >>>
# save 1 868 >>>
# save 1 876 >>>
# save 1 877 >>>
# save 1 882 >>>
# save 1 893 >>>
# save 1 897 >>>
# save 1 904 >>>
# save 1 906 >>>
# save 1 912 >>>
# save 1 916 >>>
# save 1 927 >>>
# save 1 928 >>>
# save 1 960 >>>
# save 1 978 >>>
# save 1 980 >>>
# save 1 983 >>>
# save 1 1002 >>>
# save 1 1023 >>>
# save 1 1037 >>>
# save 1 1040 >>>
# save 1 1041 >>>
# save 1 1054 >>>
# save 1 1066 >>>
# save 1 1072 >>>
# save 1 1085 >>>
# save 1 1091 >>>
# save 1 1094 >>>
# save 1 1112 >>>
# save 1 1128 >>>
# save 1 1129 >>>
# save 1 1137 >>>
# save 1 1158 >>>
# save 1 1166 >>>
# save 1 1245 >>>
# save 1 1247 >>>
# save 1 1253 >>>
# save 1 1267 >>>
# save 1 1274 >>>
# save 1 1283 >>>
# save 1 1307 >>>
# save 1 1312 >>>
# save 1 1336 >>>
# save 1 1393 >>>
# save 1 1394 >>>
# save 1 1438 >>>
# {2: 10, 9: 7, 11: 21, 18: 6}
# >>> multi-class sampels
# save 2 2 >>>
# save 2 8 >>>
# save 2 16 >>>
# save 2 19 >>>
# save 2 27 >>>
# save 2 32 >>>
# save 2 34 >>>
# save 2 35 >>>
# save 2 37 >>>
# save 2 41 >>>
# save 2 45 >>>
# save 2 55 >>>
# save 2 59 >>>
# save 2 69 >>>
# save 2 75 >>>
# save 2 83 >>>
# save 2 90 >>>
# save 2 102 >>>
# save 2 109 >>>
# save 2 127 >>>
# save 2 142 >>>
# save 2 151 >>>
# save 2 152 >>>
# save 2 163 >>>
# save 2 166 >>>
# save 2 167 >>>
# save 2 168 >>>
# save 2 171 >>>
# save 2 191 >>>
# save 2 205 >>>
# save 2 214 >>>
# save 2 248 >>>
# save 2 268 >>>
# save 2 269 >>>
# save 2 288 >>>
# 491 500
# >>> the num per class constraint is unachievable
# save 3 0 >>>
# save 3 5 >>>
# save 3 12 >>>
# save 3 13 >>>
# save 3 14 >>>
# save 3 15 >>>
# save 3 21 >>>
# save 3 24 >>>
# save 3 29 >>>
# >>> sample size 500

# %%
import shutil
import os
os.rename('VOC-sample', 'VOC2012')

# %%
# !mkdir dataset
# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=$myusername&password=$mypassword&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1 -P dataset
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3 -P dataset

# !mkdir -p CAP_augmentation/data/cityscapes
# !unzip -q -o dataset/gtFine_trainvaltest.zip -d CAP_augmentation/data/cityscapes
# !unzip -q -o dataset/leftImg8bit_trainvaltest.zip -d CAP_augmentation/data/cityscapes

# !wget https://github.com/shubham0204/Dataset_Archives/blob/master/cityscape_images.zip?raw=true -O cityscape_images.zip
# !unzip cityscape_images.zip

# !wget --keep-session-cookies --save-cookies=cookies.txt --post-data 'username=yj373@cornell.edu&password=Yj373950911!&submit=Login' https://www.cityscapes-dataset.com/login/
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=1
# !wget --load-cookies cookies.txt --content-disposition https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Out:
# --2024-05-18 03:33:46--  https://www.cityscapes-dataset.com/login/
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.cityscapes-dataset.com/downloads/ [following]
# --2024-05-18 03:33:47--  https://www.cityscapes-dataset.com/downloads/
# Reusing existing connection to www.cityscapes-dataset.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html’
#
# index.html              [  <=>               ]  57.34K   189KB/s    in 0.3s
#
# 2024-05-18 03:33:48 (189 KB/s) - ‘index.html’ saved [58715]
#
# --2024-05-18 03:33:48--  https://www.cityscapes-dataset.com/file-handling/?packageID=1
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252567705 (241M) [application/octet-stream]
# Saving to: ‘gtFine_trainvaltest.zip’
#
# gtFine_trainvaltest 100%[===================>] 240.87M  21.6MB/s    in 12s
#
# 2024-05-18 03:34:01 (19.6 MB/s) - ‘gtFine_trainvaltest.zip’ saved [252567705/252567705]
#
# --2024-05-18 03:34:01--  https://www.cityscapes-dataset.com/file-handling/?packageID=3
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11592327197 (11G) [application/octet-stream]
# Saving to: ‘leftImg8bit_trainvaltest.zip’
#
# leftImg8bit_trainva 100%[===================>]  10.80G  19.5MB/s    in 9m 30s
#
# 2024-05-18 03:43:31 (19.4 MB/s) - ‘leftImg8bit_trainvaltest.zip’ saved [11592327197/11592327197]

# %%
# !mkdir cityscape
# !unzip -q -o gtFine_trainvaltest.zip -d cityscape
# !unzip -q -o leftImg8bit_trainvaltest.zip -d cityscape

# %%
import os
import shutil, random
import numpy as np
from PIL import Image
from torchvision.datasets import Cityscapes

Cityscape_label_color_map = {
    (128, 64, 128): 'road', # flat
    (220, 20, 60): 'person', # human
    (70, 70, 70): 'building', # construction
    (250, 70, 30): 'traffic light', # object
    (107,142, 35): 'vegetation', # nature
    (0, 0, 142): 'car', # vehicle
    (0, 60, 100): 'bus', # vehicle
    (0, 80, 100): 'train', # vehicle
    (0, 0, 230): 'motorcycle', # vehicle
    (119, 11, 32): 'bicycle', #vehicle
}
Cityscape_label_map = {
    1: 'road', # flat
    2: 'person', # human
    3: 'building', # construction
    4: 'traffic light', # object
    5: 'vegetation', # nature
    6: 'car', # vehicle
    7: 'bus', # vehicle
    8: 'train', # vehicle
    9: 'motorcycle', # vehicle
    10: 'bicycle', #vehicle
}
Cityscape_label_map_reverse = {
    'road': 1, # flat
    'person': 2, # human
    'building': 3, # construction
    'traffic light': 4, # object
    'vegetation': 5, # nature
    'car': 6, # vehicle
    'bus': 7, # vehicle
    'train': 8, # vehicle
    'motorcycle': 9, # vehicle
    'bicycle': 10, #vehicle
}


def sample_set_cityscape(cityscape_data, target_dir, sample_size=50):
  if os.path.isdir(target_dir):
    shutil.rmtree(target_dir)
  os.mkdir(target_dir)
  os.mkdir(os.path.join(target_dir, 'images'))
  os.mkdir(os.path.join(target_dir, 'original_segmentations'))

  sample_indices = random.sample(range(len(cityscape_data)), sample_size)
  for idx in sample_indices:
    img, col = cityscape_data[idx]
    img.save(os.path.join(target_dir, 'images', '{}.png'.format(idx)))
    col.save(os.path.join(target_dir, 'original_segmentations', '{}.png'.format(idx)))

cityscape_data = Cityscapes('./cityscape', split='train', mode='fine',
                     target_type='color')
target_dir = 'Cityscape'
# sample_set_cityscape(cityscape_data, target_dir, sample_size_per_class=5)
sample_set_cityscape(cityscape_data, target_dir, sample_size=10)
print('>>> sample size', len(os.listdir(os.path.join(target_dir, 'images'))))
# Out:
# >>> sample size 10

# %%
import os
import nltk
import numpy as np
import shutil
import torch
from PIL import Image

Cityscape_rgb_map = {
    (128, 64,128): 'road', # flat
    (220, 20, 60): 'person', # human
    (70, 70, 70): 'building', # construction
    (250, 70, 30): 'traffic light', # object
    (107,142, 35): 'vegetation', # nature
    (0, 0, 142): 'car', # vehicle
    (0, 60, 100): 'bus', # vehicle
    (0, 80, 100): 'train', # vehicle
    (0, 0, 230): 'motorcycle', # vehicle
    (119, 11, 32): 'bicycle', #vehicle
}
Cityscape_int_map = {
    (128, 64,128): 1, # flat
    (220, 20, 60): 2, # human
    (70, 70, 70): 3, # construction
    (250, 70, 30): 4, # object
    (107,142, 35): 5, # nature
    (0, 0, 142): 6, # vehicle
    (0, 60, 100): 7, # vehicle
    (0, 80, 100): 8, # vehicle
    (0, 0, 230): 9, # vehicle
    (119, 11, 32): 10, #vehicle
}
seg_voc = Image.open('VOC2012/segmentations/1.png')
trans_seg_dir = 'Cityscape/segmentations'

if os.path.isdir(trans_seg_dir):
  shutil.rmtree(trans_seg_dir)
os.mkdir(trans_seg_dir)
seg_dir = 'Cityscape/original_segmentations'

for file in os.listdir(seg_dir):
  if not file.endswith('.png'):
    continue
  seg = Image.open(os.path.join(seg_dir, file)).convert('RGB')
  # display(seg)
  seg_arr = np.asarray(seg)
  h, w = seg_arr.shape[0], seg_arr.shape[1]
  seg_arr_ = np.zeros((h, w), dtype=np.uint8)
  for i in range(h):
    for j in range(w):
      value = tuple(seg_arr[i, j, :])
      if value in Cityscape_int_map.keys():
        seg_arr_[i, j] = Cityscape_int_map[value]
  # print('>>> ', file)
  trans = Image.fromarray(seg_arr_, mode='P')
  trans.putpalette(seg_voc.palette)
  trans.save(os.path.join(trans_seg_dir, file))
  # display(trans)
  # break

# %%
import os
import shutil
import numpy as np

from PIL import Image

Cityscape_label_map = {
    1: 'road', # flat
    2: 'person', # human
    3: 'building', # construction
    4: 'traffic light', # object
    5: 'vegetation', # nature
    6: 'car', # vehicle
    7: 'bus', # vehicle
    8: 'train', # vehicle
    9: 'motorcycle', # vehicle
    10: 'bicycle', #vehicle
}

VOC_label_map = {
  1:'aeroplane',
  2:'bicycle',
  3:'bird',
  4:'boat',
  5:'bottle',
  6:'bus',
  7:'car',
  8:'cat',
  9:'chair',
  10:'cow',
  11:'diningtable',
  12:'dog',
  13:'horse',
  14:'motorbike',
  15:'person',
  16:'pottedplant',
  17:'sheep',
  18:'sofa',
  19:'train',
  20:'tvmonitor'
}

Vaihingen_label_map = {
  1: 'building'
}

Kvasir_label_map = {
  1: 'tumor'
}

def generate_cls_seg(segmentation_dir, label_map, dataset="VOC2012"):
  cls_arr_dir = segmentation_dir.replace('segmentations', 'class_array')
  if os.path.isdir(cls_arr_dir):
    shutil.rmtree(cls_arr_dir)
  os.mkdir(cls_arr_dir)
  print('>>> ', segmentation_dir)
  for seg_file in os.listdir(segmentation_dir):
      seg_path = os.path.join(segmentation_dir, seg_file)

      if dataset == "Kvasir-SEG":
        seg = Image.open(seg_path).convert('L')
        seg_arr = np.asarray(seg)
        seg_arr = np.where(seg_arr > 200, 1, 0)
      else:
        seg = Image.open(seg_path)
        seg_arr = np.asarray(seg)
      # print(seg_arr.shape)
      seg_classes = np.unique(seg_arr)

      for cls in seg_classes:
        if cls in label_map.keys():
          seg_cls_arr = np.where(seg_arr == cls, 1, 0)
          cls_name = label_map[cls]
          with open(os.path.join(cls_arr_dir, '{}_{}.npy'.format(seg_file.split('.')[0], cls_name)), 'wb') as f:
            np.save(f, seg_cls_arr)

generate_cls_seg("VOC2012/segmentations", VOC_label_map, dataset="VOC2012")
# generate_cls_seg("Cityscape/segmentations", Cityscape_label_map, dataset="Cityscape")
# generate_cls_seg("Vaihingen/segmentations", Vaihingen_label_map, dataset="Vaihingen")
# generate_cls_seg("Kvasir-SEG/segmentations", Kvasir_label_map, dataset="Kvasir-SEG")
# Out:
# >>>  VOC2012/segmentations

# %%
import os
import nltk
import numpy as np
import torch
from PIL import Image
from transformers import CLIPProcessor, CLIPModel, BlipProcessor, BlipForConditionalGeneration, BertModel, BertTokenizer, VisionEncoderDecoderModel, ViTImageProcessor, AutoTokenizer
from torchvision import transforms
from scipy.spatial.distance import cosine
from nltk.stem import WordNetLemmatizer

device = "cuda:0"
blip_processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large").to(device)

vit_gpt2_model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning").to(device)
vit_gpt2_feature_extractor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
vit_gpt2_tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

model_name = 'bert-base-uncased'
bert_tokenizer = BertTokenizer.from_pretrained(model_name)
bert_model = BertModel.from_pretrained(model_name)
# Out:
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
import os
import numpy as np
import json
from PIL import Image
VOC_label_map = {
  1:'aeroplane',
  2:'bicycle',
  3:'bird',
  4:'boat',
  5:'bottle',
  6:'bus',
  7:'car',
  8:'cat',
  9:'chair',
  10:'cow',
  11:'diningtable',
  12:'dog',
  13:'horse',
  14:'motorbike',
  15:'person',
  16:'pottedplant',
  17:'sheep',
  18:'sofa',
  19:'train',
  20:'tvmonitor'
}

Vaihingen_label_map = {
  1: 'building'
}

# Kvasir_label_map = {
#   1: 'polyp'
# }
Kvasir_label_map2 = {
  1: 'tumor'
}

Cityscape_label_map = {
  1: 'road', # flat
  2: 'person', # human
  3: 'building', # construction
  4: 'traffic light', # object
  5: 'vegetation', # nature
  6: 'car', # vehicle
  7: 'bus', # vehicle
  8: 'train', # vehicle
  9: 'motorcycle', # vehicle
  10: 'bicycle', #vehicle
}


def get_emb_by_idx(sentence, bert_tokenizer, bert_model, noun_dict):
  tokens = bert_tokenizer.tokenize(sentence)
  token_id = bert_tokenizer.convert_tokens_to_ids(tokens)
  input_ids = torch.tensor([token_id])
  with torch.no_grad():
    outputs = bert_model(input_ids)
    word_embeddings = outputs.last_hidden_state
  embs = []
  # for idx in indices:
  #   emb = word_embeddings.squeeze()[idx, :]
  #   embs.append(emb)
  for n in noun_dict.keys():
    emb_ = None
    for idx in noun_dict[n]:
      if emb_ is None:
        emb_ = word_embeddings.squeeze()[idx, :]
      else:
        emb_ += word_embeddings.squeeze()[idx, :]
    emb_ /= len(noun_dict[n])
    embs.append(emb_)
  return embs


def get_aug_cls(prompt, seg, label_map, thres=0.8):
  words = nltk.word_tokenize(prompt)
  tagged_words = nltk.tag.pos_tag(words)
  lemmatizer = WordNetLemmatizer()
  # nouns = []
  # noun_positions = []
  noun_dict = {}
  for i, (word, pos) in enumerate(tagged_words):
    if pos.startswith('N'):
      word = lemmatizer.lemmatize(word)
      if word in noun_dict.keys():
        noun_dict[word].append(i)
      else:
        noun_dict[word] = [i]

  print(noun_dict)
  seg_arr = np.asarray(seg).astype(np.uint8)
  cls_values = np.unique(seg_arr)
  embs = get_emb_by_idx(prompt, bert_tokenizer, bert_model, noun_dict)
  aug_labels = {}
  for cls in cls_values:
    if cls not in label_map.keys():
      continue
    cls_name = label_map[cls]
    print('>>> class name: {}'.format(cls_name))
    cls_aug = []
    for i, (noun, indices) in enumerate(noun_dict.items()):
      if cls_name == noun:
        continue
      prompt = prompt.replace(noun, cls_name)
      print(prompt)
      emb = get_emb_by_idx(prompt, bert_tokenizer, bert_model, {noun: indices})
      similarity = 1.0 - cosine(embs[i], emb[0])
      print('simlarity ({}, {}): {:.4f}, idx: {}'.format(cls_name, noun, similarity, indices))
      if similarity > thres:
        cls_aug.append(noun)
      prompt = prompt.replace(cls_name, noun)
    print("augemented class: ", cls_aug)
    aug_labels[cls_name] = cls_aug

  return aug_labels

# datasets = ["VOC2012", "Kvasir-SEG", "Vaihingen", "Cityscape"]
# label_maps = [VOC_label_map, Kvasir_label_map2, Vaihingen_label_map, Cityscape_label_map]
# datasets = ["Kvasir-SEG"]
# label_maps = [Kvasir_label_map2]
datasets = ["VOC2012"]
label_maps = [VOC_label_map]
thres = 0.85
for ds, label_map in zip(datasets, label_maps):
  image_dir = os.path.join(ds, "images")
  seg_dir = os.path.join(ds, "segmentations")
  ds_aug_labels = {}
  for file in os.listdir(image_dir):
    if file.startswith('.'):
      continue
    img_path = os.path.join(image_dir, file)
    seg_path = os.path.join(seg_dir, file)
    img = Image.open(img_path)
    seg = Image.open(seg_path)

    inputs = blip_processor(img, return_tensors="pt").to(device) # processor: Blip processor
    out = blip_model.generate(**inputs)
    prompt1 = blip_processor.decode(out[0], skip_special_tokens=True)
    print('** BLIP prompt: ' + prompt1)
    aug = get_aug_cls(prompt1, seg, label_map, thres=thres)
    ds_aug_labels[img_path] = aug

  with open(os.path.join(ds, "aug_label_blip_bert_{}.json".format(thres)), "w") as outfile:
    json.dump(ds_aug_labels, outfile)
# Out:
# ** BLIP prompt: arafed scooter parked in front of a door in a stone building
# {'scooter': [1], 'front': [4], 'door': [7], 'stone': [10], 'building': [11]}
# >>> class name: motorbike
# arafed motorbike parked in front of a door in a stone building
# simlarity (motorbike, scooter): 0.8514, idx: [1]
# arafed scooter parked in motorbike of a door in a stone building
# simlarity (motorbike, front): 0.9439, idx: [4]
# arafed scooter parked in front of a motorbike in a stone building
# simlarity (motorbike, door): 0.8806, idx: [7]
# arafed scooter parked in front of a door in a motorbike building
# simlarity (motorbike, stone): 0.9253, idx: [10]
# arafed scooter parked in front of a door in a stone motorbike
# simlarity (motorbike, building): 0.7750, idx: [11]
# augemented class:  ['scooter', 'front', 'door', 'stone']
# ** BLIP prompt: arafed cargo ship in a canal with a bridge and a train
# {'ship': [2], 'canal': [5], 'bridge': [8], 'train': [11]}
# >>> class name: boat
# arafed cargo boat in a canal with a bridge and a train
# simlarity (boat, ship): 0.9720, idx: [2]
# arafed cargo ship in a boat with a bridge and a train
# simlarity (boat, canal): 0.8974, idx: [5]
# arafed cargo ship in a canal with a boat and a train
# simlarity (boat, bridge): 0.9595, idx: [8]
# arafed cargo ship in a canal with a bridge and a boat
# simlarity (boat, train): 0.9526, idx: [11]
# augemented class:  ['ship', 'canal', 'bridge', 'train']
# ** BLIP prompt: there is a sheep standing in a field of grass near a tree
# {'standing': [4], 'field': [7], 'grass': [9], 'tree': [12]}
# >>> class name: sheep
# there is a sheep sheep in a field of grass near a tree
# simlarity (sheep, standing): 0.8484, idx: [4]
# there is a standing standing in a sheep of grass near a tree
# simlarity (sheep, field): 0.7578, idx: [7]
# there is a standing standing in a field of sheep near a tree
# simlarity (sheep, grass): 0.8534, idx: [9]
# there is a standing standing in a field of grass near a sheep
# simlarity (sheep, tree): 0.8145, idx: [12]
# augemented class:  ['grass']
# ** BLIP prompt: there is a white cat laying on a white sheet on a chair
# {'cat': [4], 'sheet': [9], 'chair': [12]}
# >>> class name: cat
# there is a white cat laying on a white cat on a chair
# simlarity (cat, sheet): 0.8000, idx: [9]
# there is a white sheet laying on a white sheet on a cat
# simlarity (cat, chair): 0.7652, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a dining room table with chairs and a book shelf
# {'room': [4], 'table': [5], 'chair': [7], 'book': [10], 'shelf': [11]}
# >>> class name: chair
# there is a dining chair table with chairs and a book shelf
# simlarity (chair, room): 0.9298, idx: [4]
# there is a dining room chair with rooms and a book shelf
# simlarity (chair, table): 0.8553, idx: [5]
# there is a dining room table with rooms and a chair shelf
# simlarity (chair, book): 0.8989, idx: [10]
# there is a dining room table with rooms and a book chair
# simlarity (chair, shelf): 0.8556, idx: [11]
# augemented class:  ['room', 'table', 'book', 'shelf']
# >>> class name: diningtable
# there is a dining diningtable table with diningtables and a book shelf
# simlarity (diningtable, room): 0.8373, idx: [4]
# there is a dining room diningtable with rooms and a book shelf
# simlarity (diningtable, table): 0.8595, idx: [5]
# there is a dining room table with rooms and a book shelf
# simlarity (diningtable, chair): 0.8832, idx: [7]
# there is a dining room table with rooms and a diningtable shelf
# simlarity (diningtable, book): 0.8225, idx: [10]
# there is a dining room table with rooms and a book diningtable
# simlarity (diningtable, shelf): 0.7608, idx: [11]
# augemented class:  ['table', 'chair']
# >>> class name: sofa
# there is a dining sofa table with sofas and a book shelf
# simlarity (sofa, room): 0.8758, idx: [4]
# there is a dining room sofa with rooms and a book shelf
# simlarity (sofa, table): 0.8707, idx: [5]
# there is a dining room table with rooms and a book shelf
# simlarity (sofa, chair): 0.8832, idx: [7]
# there is a dining room table with rooms and a sofa shelf
# simlarity (sofa, book): 0.8955, idx: [10]
# there is a dining room table with rooms and a book sofa
# simlarity (sofa, shelf): 0.8355, idx: [11]
# augemented class:  ['room', 'table', 'chair', 'book']
# ** BLIP prompt: boats docked in a harbor with a mountain in the background
# {'boat': [0], 'harbor': [4], 'mountain': [7], 'background': [10]}
# >>> class name: boat
# boats docked in a boat with a mountain in the background
# simlarity (boat, harbor): 0.8530, idx: [4]
# harbors docked in a harbor with a boat in the background
# simlarity (boat, mountain): 0.5692, idx: [7]
# harbors docked in a harbor with a mountain in the boat
# simlarity (boat, background): 0.3485, idx: [10]
# augemented class:  ['harbor']
# ** BLIP prompt: there are two birds sitting on the rocks by the water
# {'bird': [3], 'rock': [7], 'water': [10]}
# >>> class name: bird
# there are two birds sitting on the birds by the water
# simlarity (bird, rock): 0.8212, idx: [7]
# there are two rocks sitting on the rocks by the bird
# simlarity (bird, water): 0.7301, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a horse that is laying down in the dirt
# {'horse': [3], 'dirt': [10]}
# >>> class name: horse
# there is a horse that is laying down in the horse
# simlarity (horse, dirt): 0.7145, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a sheep that is standing in a pen with a fence
# {'sheep': [3], 'pen': [9], 'fence': [12]}
# >>> class name: sheep
# there is a sheep that is standing in a sheep with a fence
# simlarity (sheep, pen): 0.8472, idx: [9]
# there is a pen that is standing in a pen with a sheep
# simlarity (sheep, fence): 0.7677, idx: [12]
# augemented class:  []
# ** BLIP prompt: arafed silver sports car driving on a track with grass in the background
# {'sport': [2], 'car': [3], 'track': [7], 'grass': [9], 'background': [12]}
# >>> class name: car
# arafed silver cars car driving on a track with grass in the background
# simlarity (car, sport): 0.8657, idx: [2]
# arafed silver sports sport driving on a car with grass in the background
# simlarity (car, track): 0.8957, idx: [7]
# arafed silver sports sport driving on a track with car in the background
# simlarity (car, grass): 0.8946, idx: [9]
# arafed silver sports sport driving on a track with grass in the car
# simlarity (car, background): 0.7214, idx: [12]
# augemented class:  ['sport', 'track', 'grass']
# ** BLIP prompt: there is a white horse running in the grass near a fence
# {'horse': [4], 'grass': [8], 'fence': [11]}
# >>> class name: horse
# there is a white horse running in the horse near a fence
# simlarity (horse, grass): 0.8051, idx: [8]
# there is a white grass running in the grass near a horse
# simlarity (horse, fence): 0.7952, idx: [11]
# augemented class:  []
# ** BLIP prompt: there is a duck that is swimming in the water
# {'duck': [3], 'water': [9]}
# >>> class name: bird
# there is a bird that is swimming in the water
# simlarity (bird, duck): 0.8695, idx: [3]
# there is a duck that is swimming in the bird
# simlarity (bird, water): 0.7743, idx: [9]
# augemented class:  ['duck']
# ** BLIP prompt: there are two cows that are laying down in the hay
# {'cow': [3], 'hay': [10]}
# >>> class name: cow
# there are two cows that are laying down in the cow
# simlarity (cow, hay): 0.7624, idx: [10]
# augemented class:  []
# ** BLIP prompt: there are many different foods on the table with wine and wine bottles
# {'food': [4], 'table': [7], 'wine': [9, 11], 'bottle': [12]}
# >>> class name: bottle
# there are many different bottles on the table with wine and wine bottles
# simlarity (bottle, food): 0.9099, idx: [4]
# there are many different foods on the bottle with wine and wine foods
# simlarity (bottle, table): 0.8377, idx: [7]
# there are many different foods on the table with bottle and bottle foods
# simlarity (bottle, wine): 0.9025, idx: [9, 11]
# augemented class:  ['food', 'wine']
# >>> class name: chair
# there are many different chairs on the table with wine and wine chairs
# simlarity (chair, food): 0.8792, idx: [4]
# there are many different foods on the chair with wine and wine foods
# simlarity (chair, table): 0.8573, idx: [7]
# there are many different foods on the table with chair and chair foods
# simlarity (chair, wine): 0.8710, idx: [9, 11]
# there are many different foods on the table with wine and wine foods
# simlarity (chair, bottle): 0.8958, idx: [12]
# augemented class:  ['food', 'table', 'wine', 'bottle']
# >>> class name: diningtable
# there are many different diningtables on the table with wine and wine diningtables
# simlarity (diningtable, food): 0.8274, idx: [4]
# there are many different foods on the diningtable with wine and wine foods
# simlarity (diningtable, table): 0.8505, idx: [7]
# there are many different foods on the table with diningtable and diningtable foods
# simlarity (diningtable, wine): 0.8111, idx: [9, 11]
# there are many different foods on the table with wine and wine foods
# simlarity (diningtable, bottle): 0.8958, idx: [12]
# augemented class:  ['table', 'bottle']
# ** BLIP prompt: people sitting on stools in front of a window with a view of a city
# {'people': [0], 'stool': [3], 'front': [5], 'window': [8], 'view': [11], 'city': [14]}
# >>> class name: person
# person sitting on stools in front of a window with a view of a city
# simlarity (person, people): 0.9038, idx: [0]
# people sitting on persons in front of a window with a view of a city
# simlarity (person, stool): 0.5883, idx: [3]
# people sitting on stools in person of a window with a view of a city
# simlarity (person, front): 0.8583, idx: [5]
# people sitting on stools in front of a person with a view of a city
# simlarity (person, window): 0.8174, idx: [8]
# people sitting on stools in front of a window with a person of a city
# simlarity (person, view): 0.7876, idx: [11]
# people sitting on stools in front of a window with a view of a person
# simlarity (person, city): 0.8366, idx: [14]
# augemented class:  ['people', 'front']
# ** BLIP prompt: there is a cat that is laying on the floor with its back legs up
# {'cat': [3], 'floor': [9], 'back': [12]}
# >>> class name: cat
# there is a cat that is laying on the cat with its back legs up
# simlarity (cat, floor): 0.7558, idx: [9]
# there is a floor that is laying on the floor with its cat legs up
# simlarity (cat, back): 0.7796, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a cat that is laying on a window sill
# {'cat': [3], 'window': [9], 'sill': [10]}
# >>> class name: cat
# there is a cat that is laying on a cat sill
# simlarity (cat, window): 0.7087, idx: [9]
# there is a window that is laying on a window cat
# simlarity (cat, sill): 0.6017, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a sheep that is standing in the dirt by a fence
# {'sheep': [3], 'dirt': [9], 'fence': [12]}
# >>> class name: sheep
# there is a sheep that is standing in the sheep by a fence
# simlarity (sheep, dirt): 0.8042, idx: [9]
# there is a dirt that is standing in the dirt by a sheep
# simlarity (sheep, fence): 0.7695, idx: [12]
# augemented class:  []
# ** BLIP prompt: arafed train on the tracks near the water and rocks
# {'train': [1], 'track': [4], 'water': [7], 'rock': [9]}
# >>> class name: train
# arafed train on the trains near the water and rocks
# simlarity (train, track): 0.8450, idx: [4]
# arafed track on the tracks near the train and rocks
# simlarity (train, water): 0.7252, idx: [7]
# arafed track on the tracks near the water and trains
# simlarity (train, rock): 0.7904, idx: [9]
# augemented class:  []
# ** BLIP prompt: there is a cat that is sitting in a christmas tree
# {'cat': [3], 'christmas': [9], 'tree': [10]}
# >>> class name: cat
# there is a cat that is sitting in a cat tree
# simlarity (cat, christmas): 0.8834, idx: [9]
# there is a christmas that is sitting in a christmas cat
# simlarity (cat, tree): 0.7809, idx: [10]
# augemented class:  ['christmas']
# ** BLIP prompt: there is a man holding a beer glass in his hand
# {'man': [3], 'beer': [6], 'glass': [7], 'hand': [10]}
# >>> class name: bottle
# there is a bottle holding a beer glass in his hand
# simlarity (bottle, man): 0.7568, idx: [3]
# there is a man holding a bottle glass in his hand
# simlarity (bottle, beer): 0.9157, idx: [6]
# there is a man holding a beer bottle in his hand
# simlarity (bottle, glass): 0.9533, idx: [7]
# there is a man holding a beer glass in his bottle
# simlarity (bottle, hand): 0.7848, idx: [10]
# augemented class:  ['beer', 'glass']
# >>> class name: person
# there is a person holding a beer glass in his hand
# simlarity (person, man): 0.8245, idx: [3]
# there is a man holding a person glass in his hand
# simlarity (person, beer): 0.7060, idx: [6]
# there is a man holding a beer person in his hand
# simlarity (person, glass): 0.7970, idx: [7]
# there is a man holding a beer glass in his person
# simlarity (person, hand): 0.7400, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a white couch and ottoman in a living room
# {'couch': [4], 'ottoman': [6], 'living': [9], 'room': [10]}
# >>> class name: sofa
# there is a white sofa and ottoman in a living room
# simlarity (sofa, couch): 0.9743, idx: [4]
# there is a white couch and sofa in a living room
# simlarity (sofa, ottoman): 0.8789, idx: [6]
# there is a white couch and ottoman in a sofa room
# simlarity (sofa, living): 0.8895, idx: [9]
# there is a white couch and ottoman in a living sofa
# simlarity (sofa, room): 0.8150, idx: [10]
# augemented class:  ['couch', 'ottoman', 'living']
# ** BLIP prompt: there is a black and white cat sitting on a window sill
# {'cat': [6], 'window': [10], 'sill': [11]}
# >>> class name: cat
# there is a black and white cat sitting on a cat sill
# simlarity (cat, window): 0.8262, idx: [10]
# there is a black and white window sitting on a window cat
# simlarity (cat, sill): 0.6943, idx: [11]
# augemented class:  []
# ** BLIP prompt: there is a cow standing on the side of the road at night
# {'standing': [4], 'side': [7], 'road': [10], 'night': [12]}
# >>> class name: cow
# there is a cow cow on the side of the road at night
# simlarity (cow, standing): 0.8979, idx: [4]
# there is a standing standing on the cow of the road at night
# simlarity (cow, side): 0.8163, idx: [7]
# there is a standing standing on the side of the cow at night
# simlarity (cow, road): 0.8372, idx: [10]
# there is a standing standing on the side of the road at cow
# simlarity (cow, night): 0.6227, idx: [12]
# augemented class:  ['standing']
# ** BLIP prompt: motorcycle parked on a wooden platform in front of a brick building
# {'motorcycle': [0], 'platform': [5], 'front': [7], 'brick': [10], 'building': [11]}
# >>> class name: motorbike
# motorbike parked on a wooden platform in front of a brick building
# simlarity (motorbike, motorcycle): 0.6308, idx: [0]
# motorcycle parked on a wooden motorbike in front of a brick building
# simlarity (motorbike, platform): 0.7192, idx: [5]
# motorcycle parked on a wooden platform in motorbike of a brick building
# simlarity (motorbike, front): 0.6752, idx: [7]
# motorcycle parked on a wooden platform in front of a motorbike building
# simlarity (motorbike, brick): 0.7717, idx: [10]
# motorcycle parked on a wooden platform in front of a brick motorbike
# simlarity (motorbike, building): 0.7392, idx: [11]
# augemented class:  []
# ** BLIP prompt: there are many bottles of beer and some food on a table
# {'bottle': [3], 'beer': [5], 'food': [8], 'table': [11]}
# >>> class name: bottle
# there are many bottles of bottle and some food on a table
# simlarity (bottle, beer): 0.9138, idx: [5]
# there are many beers of beer and some bottle on a table
# simlarity (bottle, food): 0.8269, idx: [8]
# there are many beers of beer and some food on a bottle
# simlarity (bottle, table): 0.7706, idx: [11]
# augemented class:  ['beer']
# ** BLIP prompt: there are two cows that are standing in the grass by the water
# {'cow': [3], 'grass': [9], 'water': [12]}
# >>> class name: cow
# there are two cows that are standing in the cow by the water
# simlarity (cow, grass): 0.8777, idx: [9]
# there are two grasss that are standing in the grass by the cow
# simlarity (cow, water): 0.6817, idx: [12]
# augemented class:  ['grass']
# ** BLIP prompt: sailboat in the water at sunset with sun setting in the background
# {'sailboat': [0], 'water': [3], 'sunset': [5], 'setting': [8], 'background': [11]}
# >>> class name: boat
# boat in the water at sunset with sun setting in the background
# simlarity (boat, sailboat): 0.5897, idx: [0]
# sailboat in the boat at sunset with sun setting in the background
# simlarity (boat, water): 0.9182, idx: [3]
# sailwater in the water at boat with sun setting in the background
# simlarity (boat, sunset): 0.7947, idx: [5]
# sailwater in the water at sunset with sun boat in the background
# simlarity (boat, setting): 0.7441, idx: [8]
# sailwater in the water at sunset with sun setting in the boat
# simlarity (boat, background): 0.7094, idx: [11]
# augemented class:  ['water']
# ** BLIP prompt: there are two potted plants sitting on the floor next to a window
# {'plant': [4], 'floor': [8], 'window': [12]}
# >>> class name: pottedplant
# there are two potted pottedplants sitting on the floor next to a window
# simlarity (pottedplant, plant): 0.9189, idx: [4]
# there are two potted plants sitting on the pottedplant next to a window
# simlarity (pottedplant, floor): 0.8718, idx: [8]
# there are two potted plants sitting on the floor next to a pottedplant
# simlarity (pottedplant, window): 0.8241, idx: [12]
# augemented class:  ['plant', 'floor']
# ** BLIP prompt: there are two sheep that are eating grass in the field
# {'grass': [7], 'field': [10]}
# >>> class name: sheep
# there are two sheep that are eating sheep in the field
# simlarity (sheep, grass): 0.9069, idx: [7]
# there are two grass that are eating grass in the sheep
# simlarity (sheep, field): 0.7734, idx: [10]
# augemented class:  ['grass']
# ** BLIP prompt: there is a computer desk with a monitor and a keyboard
# {'computer': [3], 'desk': [4], 'monitor': [7], 'keyboard': [10]}
# >>> class name: tvmonitor
# there is a tvmonitor desk with a monitor and a keyboard
# simlarity (tvmonitor, computer): 0.8383, idx: [3]
# there is a computer tvmonitor with a monitor and a keyboard
# simlarity (tvmonitor, desk): 0.8436, idx: [4]
# there is a computer desk with a tvmonitor and a keyboard
# simlarity (tvmonitor, monitor): 0.8997, idx: [7]
# there is a computer desk with a monitor and a tvmonitor
# simlarity (tvmonitor, keyboard): 0.8789, idx: [10]
# augemented class:  ['monitor', 'keyboard']
# ** BLIP prompt: there is a green and black motorcycle parked on the street
# {'motorcycle': [6], 'street': [10]}
# >>> class name: motorbike
# there is a green and black motorbike parked on the street
# simlarity (motorbike, motorcycle): 0.9073, idx: [6]
# there is a green and black motorcycle parked on the motorbike
# simlarity (motorbike, street): 0.7278, idx: [10]
# augemented class:  ['motorcycle']
# ** BLIP prompt: there is a bird that is eating from a bird feeder
# {'bird': [3, 9], 'feeder': [10]}
# >>> class name: bird
# there is a bird that is eating from a bird bird
# simlarity (bird, feeder): 0.7170, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a computer monitor and a laptop on a desk
# {'computer': [3], 'monitor': [4], 'laptop': [7], 'desk': [10]}
# >>> class name: tvmonitor
# there is a tvmonitor monitor and a laptop on a desk
# simlarity (tvmonitor, computer): 0.8674, idx: [3]
# there is a computer tvmonitor and a laptop on a desk
# simlarity (tvmonitor, monitor): 0.8540, idx: [4]
# there is a computer monitor and a tvmonitor on a desk
# simlarity (tvmonitor, laptop): 0.8378, idx: [7]
# there is a computer monitor and a laptop on a tvmonitor
# simlarity (tvmonitor, desk): 0.8020, idx: [10]
# augemented class:  ['computer', 'monitor']
# ** BLIP prompt: there is a boat that is sitting in the water
# {'boat': [3], 'water': [9]}
# >>> class name: boat
# there is a boat that is sitting in the boat
# simlarity (boat, water): 0.7796, idx: [9]
# augemented class:  []
# ** BLIP prompt: there are two horses standing in a field under a tree
# {'horse': [3], 'field': [7], 'tree': [10]}
# >>> class name: horse
# there are two horses standing in a horse under a tree
# simlarity (horse, field): 0.7490, idx: [7]
# there are two fields standing in a field under a horse
# simlarity (horse, tree): 0.7772, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a jeep that is parked on the rocks by the water
# {'jeep': [3], 'rock': [9], 'water': [12]}
# >>> class name: car
# there is a car that is parked on the rocks by the water
# simlarity (car, jeep): 0.9235, idx: [3]
# there is a jeep that is parked on the cars by the water
# simlarity (car, rock): 0.7928, idx: [9]
# there is a jeep that is parked on the rocks by the car
# simlarity (car, water): 0.6847, idx: [12]
# augemented class:  ['jeep']
# ** BLIP prompt: there is a plane that is flying in the sky with a kite
# {'plane': [3], 'sky': [9], 'kite': [12]}
# >>> class name: aeroplane
# there is a aeroplane that is flying in the sky with a kite
# simlarity (aeroplane, plane): 0.8926, idx: [3]
# there is a plane that is flying in the aeroplane with a kite
# simlarity (aeroplane, sky): 0.8521, idx: [9]
# there is a plane that is flying in the sky with a aeroplane
# simlarity (aeroplane, kite): 0.8370, idx: [12]
# augemented class:  ['plane', 'sky']
# ** BLIP prompt: there are two computer monitors on a desk with a keyboard and mouse
# {'computer': [3], 'monitor': [4], 'desk': [7], 'keyboard': [10], 'mouse': [12]}
# >>> class name: tvmonitor
# there are two tvmonitor monitors on a desk with a keyboard and mouse
# simlarity (tvmonitor, computer): 0.8789, idx: [3]
# there are two computer tvmonitors on a desk with a keyboard and mouse
# simlarity (tvmonitor, monitor): 0.9046, idx: [4]
# there are two computer monitors on a tvmonitor with a keyboard and mouse
# simlarity (tvmonitor, desk): 0.8874, idx: [7]
# there are two computer monitors on a desk with a tvmonitor and mouse
# simlarity (tvmonitor, keyboard): 0.8824, idx: [10]
# there are two computer monitors on a desk with a keyboard and tvmonitor
# simlarity (tvmonitor, mouse): 0.8439, idx: [12]
# augemented class:  ['computer', 'monitor', 'desk', 'keyboard']
# ** BLIP prompt: there are two planes that are sitting on the runway
# {'plane': [3], 'runway': [9]}
# >>> class name: aeroplane
# there are two aeroplanes that are sitting on the runway
# simlarity (aeroplane, plane): 0.8227, idx: [3]
# there are two planes that are sitting on the aeroplane
# simlarity (aeroplane, runway): 0.7601, idx: [9]
# augemented class:  []
# ** BLIP prompt: there is a picture of a table with a vase and pictures
# {'picture': [3, 11], 'table': [6], 'vase': [9]}
# >>> class name: bottle
# there is a bottle of a table with a vase and bottles
# simlarity (bottle, picture): 0.8294, idx: [3, 11]
# there is a picture of a bottle with a vase and pictures
# simlarity (bottle, table): 0.9110, idx: [6]
# there is a picture of a table with a bottle and pictures
# simlarity (bottle, vase): 0.8995, idx: [9]
# augemented class:  ['table', 'vase']
# ** BLIP prompt: arafied bottle of coke sitting on a counter in a dirty kitchen
# {'bottle': [1], 'coke': [3], 'counter': [7], 'dirty': [10], 'kitchen': [11]}
# >>> class name: bottle
# arafied bottle of bottle sitting on a counter in a dirty kitchen
# simlarity (bottle, coke): 0.8690, idx: [3]
# arafied coke of coke sitting on a bottle in a dirty kitchen
# simlarity (bottle, counter): 0.8642, idx: [7]
# arafied coke of coke sitting on a counter in a bottle kitchen
# simlarity (bottle, dirty): 0.8908, idx: [10]
# arafied coke of coke sitting on a counter in a dirty bottle
# simlarity (bottle, kitchen): 0.8295, idx: [11]
# augemented class:  ['coke', 'counter', 'dirty']
# ** BLIP prompt: there are two sheep standing in a pen with hay
# {'standing': [4], 'pen': [7], 'hay': [9]}
# >>> class name: sheep
# there are two sheep sheep in a pen with hay
# simlarity (sheep, standing): 0.8485, idx: [4]
# there are two standing standing in a sheep with hay
# simlarity (sheep, pen): 0.8882, idx: [7]
# there are two standing standing in a pen with sheep
# simlarity (sheep, hay): 0.8899, idx: [9]
# augemented class:  ['pen', 'hay']
# ** BLIP prompt: there are two people in a boat with a crocodile on the water
# {'people': [3], 'boat': [6], 'crocodile': [9], 'water': [12]}
# >>> class name: boat
# there are two boat in a boat with a crocodile on the water
# simlarity (boat, people): 0.7845, idx: [3]
# there are two people in a people with a boat on the water
# simlarity (boat, crocodile): 0.7964, idx: [9]
# there are two people in a people with a crocodile on the boat
# simlarity (boat, water): 0.7810, idx: [12]
# augemented class:  []
# ** BLIP prompt: there are two sheep standing behind a fence with a sign on it
# {'fence': [7], 'sign': [10]}
# >>> class name: sheep
# there are two sheep standing behind a sheep with a sign on it
# simlarity (sheep, fence): 0.8712, idx: [7]
# there are two fence standing behind a fence with a sheep on it
# simlarity (sheep, sign): 0.8051, idx: [10]
# augemented class:  ['fence']
# ** BLIP prompt: someone is sitting on a couch in a living room with their feet up
# {'someone': [0], 'couch': [5], 'living': [8], 'room': [9], 'foot': [12]}
# >>> class name: chair
# chair is sitting on a couch in a living room with their feet up
# simlarity (chair, someone): 0.9329, idx: [0]
# someone is sitting on a chair in a living room with their feet up
# simlarity (chair, couch): 0.9162, idx: [5]
# someone is sitting on a couch in a chair room with their feet up
# simlarity (chair, living): 0.8249, idx: [8]
# someone is sitting on a couch in a living chair with their feet up
# simlarity (chair, room): 0.8817, idx: [9]
# someone is sitting on a couch in a living room with their feet up
# simlarity (chair, foot): 1.0000, idx: [12]
# augemented class:  ['someone', 'couch', 'room', 'foot']
# >>> class name: diningtable
# diningtable is sitting on a couch in a living room with their feet up
# simlarity (diningtable, someone): 0.7343, idx: [0]
# someone is sitting on a diningtable in a living room with their feet up
# simlarity (diningtable, couch): 0.8150, idx: [5]
# someone is sitting on a couch in a diningtable room with their feet up
# simlarity (diningtable, living): 0.8946, idx: [8]
# someone is sitting on a couch in a living diningtable with their feet up
# simlarity (diningtable, room): 0.7747, idx: [9]
# someone is sitting on a couch in a living room with their feet up
# simlarity (diningtable, foot): 1.0000, idx: [12]
# augemented class:  ['living', 'foot']
# >>> class name: sofa
# sofa is sitting on a couch in a living room with their feet up
# simlarity (sofa, someone): 0.8445, idx: [0]
# someone is sitting on a sofa in a living room with their feet up
# simlarity (sofa, couch): 0.9627, idx: [5]
# someone is sitting on a couch in a sofa room with their feet up
# simlarity (sofa, living): 0.8609, idx: [8]
# someone is sitting on a couch in a living sofa with their feet up
# simlarity (sofa, room): 0.8467, idx: [9]
# someone is sitting on a couch in a living room with their feet up
# simlarity (sofa, foot): 1.0000, idx: [12]
# augemented class:  ['couch', 'living', 'foot']
# ** BLIP prompt: arafly docked cruise ship in a harbor with a city in the background
# {'arafly': [0], 'ship': [3], 'harbor': [6], 'city': [9], 'background': [12]}
# >>> class name: boat
# boat docked cruise ship in a harbor with a city in the background
# simlarity (boat, arafly): 0.6497, idx: [0]
# arafly docked cruise boat in a harbor with a city in the background
# simlarity (boat, ship): 0.9706, idx: [3]
# arafly docked cruise ship in a boat with a city in the background
# simlarity (boat, harbor): 0.9190, idx: [6]
# arafly docked cruise ship in a harbor with a boat in the background
# simlarity (boat, city): 0.9260, idx: [9]
# arafly docked cruise ship in a harbor with a city in the boat
# simlarity (boat, background): 0.7809, idx: [12]
# augemented class:  ['ship', 'harbor', 'city']
# ** BLIP prompt: there is a television that is sitting on a shelf in a room
# {'television': [3], 'shelf': [9], 'room': [12]}
# >>> class name: tvmonitor
# there is a tvmonitor that is sitting on a shelf in a room
# simlarity (tvmonitor, television): 0.8315, idx: [3]
# there is a television that is sitting on a tvmonitor in a room
# simlarity (tvmonitor, shelf): 0.7893, idx: [9]
# there is a television that is sitting on a shelf in a tvmonitor
# simlarity (tvmonitor, room): 0.7997, idx: [12]
# augemented class:  []
# ** BLIP prompt: araflane flying over a building with a sky background
# {'araflane': [0], 'building': [4], 'sky': [7], 'background': [8]}
# >>> class name: aeroplane
# aeroplane flying over a building with a sky background
# simlarity (aeroplane, araflane): 0.3471, idx: [0]
# araflane flying over a aeroplane with a sky background
# simlarity (aeroplane, building): 0.9096, idx: [4]
# araflane flying over a building with a aeroplane background
# simlarity (aeroplane, sky): 0.9488, idx: [7]
# araflane flying over a building with a sky aeroplane
# simlarity (aeroplane, background): 0.8356, idx: [8]
# augemented class:  ['building', 'sky']
# ** BLIP prompt: arafed computer monitor sitting on top of a white computer
# {'computer': [1, 9], 'monitor': [2], 'top': [5]}
# >>> class name: tvmonitor
# arafed tvmonitor monitor sitting on top of a white tvmonitor
# simlarity (tvmonitor, computer): 0.8294, idx: [1, 9]
# arafed computer tvmonitor sitting on top of a white computer
# simlarity (tvmonitor, monitor): 0.9061, idx: [2]
# arafed computer monitor sitting on tvmonitor of a white computer
# simlarity (tvmonitor, top): 0.8280, idx: [5]
# augemented class:  ['monitor']
# ** BLIP prompt: arafed woman with a blue jacket and a blue shirt
# {'woman': [1], 'blue': [4], 'jacket': [5], 'shirt': [9]}
# >>> class name: person
# arafed person with a blue jacket and a blue shirt
# simlarity (person, woman): 0.9260, idx: [1]
# arafed woman with a person jacket and a person shirt
# simlarity (person, blue): 0.9124, idx: [4]
# arafed woman with a blue person and a blue shirt
# simlarity (person, jacket): 0.9049, idx: [5]
# arafed woman with a blue jacket and a blue person
# simlarity (person, shirt): 0.8597, idx: [9]
# augemented class:  ['woman', 'blue', 'jacket', 'shirt']
# ** BLIP prompt: there is a white horse running in a field of grass
# {'horse': [4], 'field': [8], 'grass': [10]}
# >>> class name: horse
# there is a white horse running in a horse of grass
# simlarity (horse, field): 0.8446, idx: [8]
# there is a white field running in a field of horse
# simlarity (horse, grass): 0.6932, idx: [10]
# augemented class:  []
# ** BLIP prompt: there are two trains that are on the tracks near a building
# {'train': [3], 'track': [8], 'building': [11]}
# >>> class name: train
# there are two trains that are on the trains near a building
# simlarity (train, track): 0.8742, idx: [8]
# there are two tracks that are on the tracks near a train
# simlarity (train, building): 0.8082, idx: [11]
# augemented class:  ['track']
# ** BLIP prompt: arafed roof on a bus station with a bus parked under it
# {'roof': [1], 'bus': [4, 8], 'station': [5]}
# >>> class name: bus
# arafed bus on a bus station with a bus parked under it
# simlarity (bus, roof): 0.8521, idx: [1]
# arafed roof on a roof bus with a roof parked under it
# simlarity (bus, station): 0.7479, idx: [5]
# augemented class:  ['roof']
# ** BLIP prompt: arafed bus parked on the side of the road with a trailer attached to it
# {'bus': [1], 'side': [5], 'road': [8], 'trailer': [11]}
# >>> class name: bus
# arafed bus parked on the bus of the road with a trailer attached to it
# simlarity (bus, side): 0.8305, idx: [5]
# arafed side parked on the side of the bus with a trailer attached to it
# simlarity (bus, road): 0.8446, idx: [8]
# arafed side parked on the side of the road with a bus attached to it
# simlarity (bus, trailer): 0.9286, idx: [11]
# augemented class:  ['trailer']
# ** BLIP prompt: tables and chairs under umbrellas in a park with trees
# {'table': [0], 'chair': [2], 'umbrella': [4], 'park': [7], 'tree': [9]}
# >>> class name: chair
# chairs and chairs under umbrellas in a park with trees
# simlarity (chair, table): 0.9327, idx: [0]
# tables and tables under chairs in a park with trees
# simlarity (chair, umbrella): 0.8015, idx: [4]
# tables and tables under umbrellas in a chair with trees
# simlarity (chair, park): 0.8023, idx: [7]
# tables and tables under umbrellas in a park with chairs
# simlarity (chair, tree): 0.8646, idx: [9]
# augemented class:  ['table', 'tree']
# >>> class name: diningtable
# diningtables and diningtables under umbrellas in a park with trees
# simlarity (diningtable, table): 0.7548, idx: [0]
# tables and tables under umbrellas in a park with trees
# simlarity (diningtable, chair): 0.9078, idx: [2]
# tables and tables under diningtables in a park with trees
# simlarity (diningtable, umbrella): 0.6427, idx: [4]
# tables and tables under umbrellas in a diningtable with trees
# simlarity (diningtable, park): 0.8339, idx: [7]
# tables and tables under umbrellas in a park with diningtables
# simlarity (diningtable, tree): 0.8241, idx: [9]
# augemented class:  ['chair']
# ** BLIP prompt: there is a cat that is laying down on a chair
# {'cat': [3], 'chair': [10]}
# >>> class name: cat
# there is a cat that is laying down on a cat
# simlarity (cat, chair): 0.7080, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a cow that is standing in the grass on a hill
# {'cow': [3], 'grass': [9], 'hill': [12]}
# >>> class name: cow
# there is a cow that is standing in the cow on a hill
# simlarity (cow, grass): 0.8197, idx: [9]
# there is a grass that is standing in the grass on a cow
# simlarity (cow, hill): 0.7521, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a large cruise ship that is docked in the water
# {'cruise': [4], 'ship': [5], 'water': [11]}
# >>> class name: boat
# there is a large boat ship that is docked in the water
# simlarity (boat, cruise): 0.9002, idx: [4]
# there is a large cruise boat that is docked in the water
# simlarity (boat, ship): 0.9312, idx: [5]
# there is a large cruise ship that is docked in the boat
# simlarity (boat, water): 0.7760, idx: [11]
# augemented class:  ['cruise', 'ship']
# ** BLIP prompt: arafed view of a plane wing from the ground with a runway in the background
# {'view': [1], 'plane': [4], 'ground': [8], 'runway': [11], 'background': [14]}
# >>> class name: aeroplane
# arafed aeroplane of a plane wing from the ground with a runway in the background
# simlarity (aeroplane, view): 0.7605, idx: [1]
# arafed view of a aeroplane wing from the ground with a runway in the background
# simlarity (aeroplane, plane): 0.9589, idx: [4]
# arafed view of a plane wing from the aeroplane with a runway in the backaeroplane
# simlarity (aeroplane, ground): 0.7320, idx: [8]
# arafed view of a plane wing from the ground with a aeroplane in the background
# simlarity (aeroplane, runway): 0.8995, idx: [11]
# arafed view of a plane wing from the ground with a runway in the aeroplane
# simlarity (aeroplane, background): 0.6541, idx: [14]
# augemented class:  ['plane', 'runway']
# ** BLIP prompt: there are many posters on the wall of a building with graffiti
# {'poster': [3], 'wall': [6], 'building': [9], 'graffiti': [11]}
# >>> class name: person
# there are many persons on the wall of a building with graffiti
# simlarity (person, poster): 0.8035, idx: [3]
# there are many posters on the person of a building with graffiti
# simlarity (person, wall): 0.8166, idx: [6]
# there are many posters on the wall of a person with graffiti
# simlarity (person, building): 0.8808, idx: [9]
# there are many posters on the wall of a building with person
# simlarity (person, graffiti): 0.8422, idx: [11]
# augemented class:  ['building']
# ** BLIP prompt: arafed train on the tracks with a train crossing in the background
# {'train': [1, 7], 'track': [4], 'crossing': [8], 'background': [11]}
# >>> class name: train
# arafed train on the trains with a train crossing in the background
# simlarity (train, track): 0.8596, idx: [4]
# arafed track on the tracks with a track train in the background
# simlarity (train, crossing): 0.7880, idx: [8]
# arafed track on the tracks with a track crossing in the train
# simlarity (train, background): 0.6499, idx: [11]
# augemented class:  ['track']
# ** BLIP prompt: cows grazing in a field of grass with trees in the background
# {'cow': [0], 'field': [4], 'grass': [6], 'tree': [8], 'background': [11]}
# >>> class name: cow
# cows grazing in a cow of grass with trees in the background
# simlarity (cow, field): 0.6886, idx: [4]
# fields grazing in a field of cow with trees in the background
# simlarity (cow, grass): 0.5620, idx: [6]
# fields grazing in a field of grass with cows in the background
# simlarity (cow, tree): 0.8381, idx: [8]
# fields grazing in a field of grass with trees in the cow
# simlarity (cow, background): 0.6255, idx: [11]
# augemented class:  []
# ** BLIP prompt: araflane jet airliner on runway with airport in background
# {'araflane': [0], 'jet': [1], 'airliner': [2], 'runway': [4], 'airport': [6], 'background': [8]}
# >>> class name: aeroplane
# aeroplane jet airliner on runway with airport in background
# simlarity (aeroplane, araflane): 0.6822, idx: [0]
# araflane aeroplane airliner on runway with airport in background
# simlarity (aeroplane, jet): 0.9655, idx: [1]
# araflane jet aeroplane on runway with airport in background
# simlarity (aeroplane, airliner): 0.9543, idx: [2]
# araflane jet airliner on aeroplane with airport in background
# simlarity (aeroplane, runway): 0.9141, idx: [4]
# araflane jet airliner on runway with aeroplane in background
# simlarity (aeroplane, airport): 0.9463, idx: [6]
# araflane jet airliner on runway with airport in aeroplane
# simlarity (aeroplane, background): 0.8648, idx: [8]
# augemented class:  ['jet', 'airliner', 'runway', 'airport', 'background']
# ** BLIP prompt: there is a bottle sitting on the ground with rocks in the background
# {'ground': [7], 'rock': [9], 'background': [12]}
# >>> class name: bottle
# there is a bottle sitting on the bottle with rocks in the backbottle
# simlarity (bottle, ground): 0.6420, idx: [7]
# there is a ground sitting on the ground with bottles in the background
# simlarity (bottle, rock): 0.8464, idx: [9]
# there is a ground sitting on the ground with rocks in the bottle
# simlarity (bottle, background): 0.7147, idx: [12]
# augemented class:  []
# ** BLIP prompt: there are two rams walking on a snowy hill together
# {'ram': [3], 'snowy': [7], 'hill': [8]}
# >>> class name: sheep
# there are two sheeps walking on a snowy hill together
# simlarity (sheep, ram): 0.8280, idx: [3]
# there are two rams walking on a sheep hill together
# simlarity (sheep, snowy): 0.8420, idx: [7]
# there are two rams walking on a snowy sheep together
# simlarity (sheep, hill): 0.8771, idx: [8]
# augemented class:  ['hill']
# ** BLIP prompt: there is a man sitting on a rock with a bike helmet on
# {'man': [3], 'rock': [7], 'bike': [10], 'helmet': [11]}
# >>> class name: person
# there is a person sitting on a rock with a bike helmet on
# simlarity (person, man): 0.8509, idx: [3]
# there is a man sitting on a person with a bike helmet on
# simlarity (person, rock): 0.7157, idx: [7]
# there is a man sitting on a rock with a person helmet on
# simlarity (person, bike): 0.8258, idx: [10]
# there is a man sitting on a rock with a bike person on
# simlarity (person, helmet): 0.8430, idx: [11]
# augemented class:  ['man']
# ** BLIP prompt: woman reading a book at a table with a plate of food
# {'woman': [0], 'book': [3], 'table': [6], 'plate': [9], 'food': [11]}
# >>> class name: diningtable
# diningtable reading a book at a table with a plate of food
# simlarity (diningtable, woman): 0.7930, idx: [0]
# woman reading a diningtable at a table with a plate of food
# simlarity (diningtable, book): 0.8080, idx: [3]
# woman reading a book at a diningtable with a plate of food
# simlarity (diningtable, table): 0.7851, idx: [6]
# woman reading a book at a table with a diningtable of food
# simlarity (diningtable, plate): 0.7647, idx: [9]
# woman reading a book at a table with a plate of diningtable
# simlarity (diningtable, food): 0.7249, idx: [11]
# augemented class:  []
# >>> class name: person
# person reading a book at a table with a plate of food
# simlarity (person, woman): 0.9056, idx: [0]
# woman reading a person at a table with a plate of food
# simlarity (person, book): 0.6864, idx: [3]
# woman reading a book at a person with a plate of food
# simlarity (person, table): 0.6334, idx: [6]
# woman reading a book at a table with a person of food
# simlarity (person, plate): 0.6431, idx: [9]
# woman reading a book at a table with a plate of person
# simlarity (person, food): 0.7108, idx: [11]
# augemented class:  ['woman']
# ** BLIP prompt: there is a sheep with a number on it standing in the grass
# {'number': [6], 'grass': [12]}
# >>> class name: sheep
# there is a sheep with a sheep on it standing in the grass
# simlarity (sheep, number): 0.7583, idx: [6]
# there is a number with a number on it standing in the sheep
# simlarity (sheep, grass): 0.7931, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a cow standing in a field with mountains in the background
# {'standing': [4], 'field': [7], 'mountain': [9], 'background': [12]}
# >>> class name: cow
# there is a cow cow in a field with mountains in the background
# simlarity (cow, standing): 0.8790, idx: [4]
# there is a standing standing in a cow with mountains in the background
# simlarity (cow, field): 0.7981, idx: [7]
# there is a standing standing in a field with cows in the background
# simlarity (cow, mountain): 0.8385, idx: [9]
# there is a standing standing in a field with mountains in the cow
# simlarity (cow, background): 0.6044, idx: [12]
# augemented class:  ['standing']
# ** BLIP prompt: there is a cow walking along the side of a river
# {'walking': [4], 'side': [7], 'river': [10]}
# >>> class name: cow
# there is a cow cow along the side of a river
# simlarity (cow, walking): 0.8002, idx: [4]
# there is a walking walking along the cow of a river
# simlarity (cow, side): 0.7774, idx: [7]
# there is a walking walking along the side of a cow
# simlarity (cow, river): 0.8421, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a cat that is laying on a table with a cord
# {'cat': [3], 'table': [9], 'cord': [12]}
# >>> class name: cat
# there is a cat that is laying on a cat with a cord
# simlarity (cat, table): 0.7728, idx: [9]
# there is a table that is laying on a table with a cat
# simlarity (cat, cord): 0.6729, idx: [12]
# augemented class:  []
# ** BLIP prompt: puppy looking at camera with sad look on face
# {'camera': [3], 'look': [6], 'face': [8]}
# >>> class name: dog
# puppy looking at dog with sad look on face
# simlarity (dog, camera): 0.7342, idx: [3]
# puppy doging at camera with sad dog on face
# simlarity (dog, look): 0.6559, idx: [6]
# puppy looking at camera with sad look on dog
# simlarity (dog, face): 0.8525, idx: [8]
# augemented class:  ['face']
# ** BLIP prompt: there is a brown horse with a white spot on it's face
# {'horse': [4], 'spot': [8], 'face': [12]}
# >>> class name: horse
# there is a brown horse with a white horse on it's face
# simlarity (horse, spot): 0.8412, idx: [8]
# there is a brown spot with a white spot on it's horse
# simlarity (horse, face): 0.7726, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a street sign that says cool on the corner
# {'street': [3], 'sign': [4], 'cool': [7], 'corner': [10]}
# >>> class name: car
# there is a car sign that says cool on the corner
# simlarity (car, street): 0.8859, idx: [3]
# there is a street car that says cool on the corner
# simlarity (car, sign): 0.8649, idx: [4]
# there is a street sign that says car on the corner
# simlarity (car, cool): 0.7851, idx: [7]
# there is a street sign that says cool on the car
# simlarity (car, corner): 0.6475, idx: [10]
# augemented class:  ['street', 'sign']
# ** BLIP prompt: there is a television that is on a stand in the room
# {'television': [3], 'stand': [8], 'room': [11]}
# >>> class name: tvmonitor
# there is a tvmonitor that is on a stand in the room
# simlarity (tvmonitor, television): 0.8493, idx: [3]
# there is a television that is on a tvmonitor in the room
# simlarity (tvmonitor, stand): 0.7797, idx: [8]
# there is a television that is on a stand in the tvmonitor
# simlarity (tvmonitor, room): 0.6949, idx: [11]
# augemented class:  []
# ** BLIP prompt: there are two buses parked in a parking lot next to each other
# {'bus': [3], 'parking': [7], 'lot': [8]}
# >>> class name: bus
# there are two buses parked in a bus lot next to each other
# simlarity (bus, parking): 0.8940, idx: [7]
# there are two parkinges parked in a parking bus next to each other
# simlarity (bus, lot): 0.7478, idx: [8]
# augemented class:  ['parking']
# ** BLIP prompt: arafed bus on the street with a blue and white stripe
# {'bus': [1], 'street': [4], 'blue': [7], 'stripe': [10]}
# >>> class name: bus
# arafed bus on the bus with a blue and white stripe
# simlarity (bus, street): 0.7997, idx: [4]
# arafed street on the street with a bus and white stripe
# simlarity (bus, blue): 0.8233, idx: [7]
# arafed street on the street with a blue and white bus
# simlarity (bus, stripe): 0.8539, idx: [10]
# augemented class:  ['stripe']
# ** BLIP prompt: arafed train on the tracks with a sky background
# {'train': [1], 'track': [4], 'sky': [7], 'background': [8]}
# >>> class name: train
# arafed train on the trains with a sky background
# simlarity (train, track): 0.8704, idx: [4]
# arafed track on the tracks with a train background
# simlarity (train, sky): 0.8533, idx: [7]
# arafed track on the tracks with a sky train
# simlarity (train, background): 0.8059, idx: [8]
# augemented class:  ['track', 'sky']
# ** BLIP prompt: there is a cat that is laying in a bag on the floor
# {'cat': [3], 'bag': [9], 'floor': [12]}
# >>> class name: cat
# there is a cat that is laying in a cat on the floor
# simlarity (cat, bag): 0.7937, idx: [9]
# there is a bag that is laying in a bag on the cat
# simlarity (cat, floor): 0.6827, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a table with a plate and a bowl of food on it
# {'table': [3], 'plate': [6], 'bowl': [9], 'food': [11]}
# >>> class name: chair
# there is a chair with a plate and a bowl of food on it
# simlarity (chair, table): 0.9242, idx: [3]
# there is a table with a chair and a bowl of food on it
# simlarity (chair, plate): 0.9339, idx: [6]
# there is a table with a plate and a chair of food on it
# simlarity (chair, bowl): 0.8820, idx: [9]
# there is a table with a plate and a bowl of chair on it
# simlarity (chair, food): 0.7990, idx: [11]
# augemented class:  ['table', 'plate', 'bowl']
# >>> class name: diningtable
# there is a diningtable with a plate and a bowl of food on it
# simlarity (diningtable, table): 0.8220, idx: [3]
# there is a table with a diningtable and a bowl of food on it
# simlarity (diningtable, plate): 0.8356, idx: [6]
# there is a table with a plate and a diningtable of food on it
# simlarity (diningtable, bowl): 0.8358, idx: [9]
# there is a table with a plate and a bowl of diningtable on it
# simlarity (diningtable, food): 0.7864, idx: [11]
# augemented class:  []
# ** BLIP prompt: there is a computer on a desk with a keyboard and monitor
# {'computer': [3], 'desk': [6], 'keyboard': [9], 'monitor': [11]}
# >>> class name: tvmonitor
# there is a tvmonitor on a desk with a keyboard and monitor
# simlarity (tvmonitor, computer): 0.8162, idx: [3]
# there is a computer on a tvmonitor with a keyboard and monitor
# simlarity (tvmonitor, desk): 0.8189, idx: [6]
# there is a computer on a desk with a tvmonitor and monitor
# simlarity (tvmonitor, keyboard): 0.8657, idx: [9]
# there is a computer on a desk with a keyboard and tvmonitor
# simlarity (tvmonitor, monitor): 0.8229, idx: [11]
# augemented class:  ['keyboard']
# ** BLIP prompt: arafed train on the tracks at a train station at night
# {'train': [1, 7], 'track': [4], 'station': [8], 'night': [10]}
# >>> class name: train
# arafed train on the trains at a train station at night
# simlarity (train, track): 0.9106, idx: [4]
# arafed track on the tracks at a track train at night
# simlarity (train, station): 0.8034, idx: [8]
# arafed track on the tracks at a track station at train
# simlarity (train, night): 0.6522, idx: [10]
# augemented class:  ['track']
# ** BLIP prompt: there is a cat sitting on the floor in front of a door
# {'cat': [3], 'floor': [7], 'front': [9], 'door': [12]}
# >>> class name: cat
# there is a cat sitting on the cat in front of a door
# simlarity (cat, floor): 0.7764, idx: [7]
# there is a floor sitting on the floor in cat of a door
# simlarity (cat, front): 0.7099, idx: [9]
# there is a floor sitting on the floor in front of a cat
# simlarity (cat, door): 0.7607, idx: [12]
# augemented class:  []
# ** BLIP prompt: there is a black and white cat laying on a couch
# {'cat': [6], 'couch': [10]}
# >>> class name: cat
# there is a black and white cat laying on a cat
# simlarity (cat, couch): 0.7089, idx: [10]
# augemented class:  []
# >>> class name: sofa
# there is a black and white couch laying on a couch
# simlarity (sofa, cat): 0.7097, idx: [6]
# there is a black and white sofa laying on a sofa
# simlarity (sofa, couch): 0.7170, idx: [10]
# ...
# augemented class:  []
# >>> class name: person
# person parked on the side of the road with a truck in the background
# simlarity (person, motorcycle): 0.9530, idx: [0]
# motorcycle parked on the person of the road with a truck in the background
# simlarity (person, side): 0.6125, idx: [4]
# motorcycle parked on the side of the person with a truck in the background
# simlarity (person, road): 0.7148, idx: [7]
# motorcycle parked on the side of the road with a person in the background
# simlarity (person, truck): 0.8630, idx: [10]
# motorcycle parked on the side of the road with a truck in the person
# simlarity (person, background): 0.6773, idx: [13]
# augemented class:  ['motorcycle', 'truck']
# ** BLIP prompt: there is a horse that is walking around in the dirt
# {'horse': [3], 'dirt': [10]}
# >>> class name: horse
# there is a horse that is walking around in the horse
# simlarity (horse, dirt): 0.7356, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a black and white cat laying on a bed
# {'cat': [6], 'bed': [10]}
# >>> class name: cat
# there is a black and white cat laying on a cat
# simlarity (cat, bed): 0.7875, idx: [10]
# augemented class:  []
# ** BLIP prompt: there is a potted plant sitting on a window sill
# {'plant': [4], 'window': [8], 'sill': [9]}
# >>> class name: pottedplant
# there is a potted pottedplant sitting on a window sill
# simlarity (pottedplant, plant): 0.9113, idx: [4]
# there is a potted plant sitting on a pottedplant sill
# simlarity (pottedplant, window): 0.8387, idx: [8]
# there is a potted plant sitting on a window pottedplant
# simlarity (pottedplant, sill): 0.8525, idx: [9]
# augemented class:  ['plant', 'sill']
# ** BLIP prompt: there is a large jetliner flying through the sky on a clear day
# {'jetliner': [4], 'sky': [8], 'day': [12]}
# >>> class name: aeroplane
# there is a large aeroplane flying through the sky on a clear day
# simlarity (aeroplane, jetliner): 0.8529, idx: [4]
# there is a large jetliner flying through the aeroplane on a clear day
# simlarity (aeroplane, sky): 0.7231, idx: [8]
# there is a large jetliner flying through the sky on a clear aeroplane
# simlarity (aeroplane, day): 0.7335, idx: [12]
# augemented class:  ['jetliner']
# ** BLIP prompt: there is a bed and a table in a small room
# {'bed': [3], 'table': [6], 'room': [10]}
# >>> class name: diningtable
# there is a diningtable and a table in a small room
# simlarity (diningtable, bed): 0.8890, idx: [3]
# there is a bed and a diningtable in a small room
# simlarity (diningtable, table): 0.8555, idx: [6]
# there is a bed and a table in a small diningtable
# simlarity (diningtable, room): 0.8186, idx: [10]
# augemented class:  ['bed', 'table']
# ** BLIP prompt: doorway leading to a patio with a table and chairs
# {'patio': [4], 'table': [7], 'chair': [9]}
# >>> class name: chair
# doorway leading to a chair with a table and chairs
# simlarity (chair, patio): 0.7628, idx: [4]
# doorway leading to a patio with a chair and patios
# simlarity (chair, table): 0.8136, idx: [7]
# augemented class:  []
# ** BLIP prompt: there are two sheep that are standing together in the grass
# {'grass': [10]}
# >>> class name: sheep
# there are two sheep that are standing together in the sheep
# simlarity (sheep, grass): 0.7670, idx: [10]
# augemented class:  []
# ** BLIP prompt: arafian air canada plane on runway with buildings in background
# {'air': [1], 'canada': [2], 'plane': [3], 'runway': [5], 'building': [7], 'background': [9]}
# >>> class name: aeroplane
# arafian aeroplane canada plane on runway with buildings in background
# simlarity (aeroplane, air): 0.9651, idx: [1]
# arafian air aeroplane plane on runway with buildings in background
# simlarity (aeroplane, canada): 0.9405, idx: [2]
# arafian air canada aeroplane on runway with buildings in background
# simlarity (aeroplane, plane): 0.9630, idx: [3]
# arafian air canada plane on aeroplane with buildings in background
# simlarity (aeroplane, runway): 0.9059, idx: [5]
# arafian air canada plane on runway with aeroplanes in background
# simlarity (aeroplane, building): 0.9381, idx: [7]
# arafian air canada plane on runway with buildings in aeroplane
# simlarity (aeroplane, background): 0.8329, idx: [9]
# augemented class:  ['air', 'canada', 'plane', 'runway', 'building']
# ** BLIP prompt: there is a bike that is parked on a trail in the woods
# {'bike': [3], 'trail': [9], 'wood': [12]}
# >>> class name: bicycle
# there is a bicycle that is parked on a trail in the woods
# simlarity (bicycle, bike): 0.9651, idx: [3]
# there is a bike that is parked on a bicycle in the woods
# simlarity (bicycle, trail): 0.8544, idx: [9]
# there is a bike that is parked on a trail in the bicycles
# simlarity (bicycle, wood): 0.6574, idx: [12]
# augemented class:  ['bike', 'trail']
# ** BLIP prompt: blond woman with sunglasses smiling at camera in airport terminal
# {'blond': [0], 'woman': [1], 'sunglass': [3], 'camera': [6], 'airport': [8], 'terminal': [9]}
# >>> class name: person
# person woman with sunglasses smiling at camera in airport terminal
# simlarity (person, blond): 0.6737, idx: [0]
# blond person with sunglasses smiling at camera in airport terminal
# simlarity (person, woman): 0.9147, idx: [1]
# blond woman with persones smiling at camera in airport terminal
# simlarity (person, sunglass): 0.7485, idx: [3]
# blond woman with sunglasses smiling at person in airport terminal
# simlarity (person, camera): 0.7964, idx: [6]
# blond woman with sunglasses smiling at camera in person terminal
# simlarity (person, airport): 0.7247, idx: [8]
# blond woman with sunglasses smiling at camera in airport person
# simlarity (person, terminal): 0.8452, idx: [9]
# augemented class:  ['woman']
# ** BLIP prompt: there is a laptop computer sitting on a table with a chair
# {'computer': [4], 'table': [8], 'chair': [11]}
# >>> class name: tvmonitor
# there is a laptop tvmonitor sitting on a table with a chair
# simlarity (tvmonitor, computer): 0.8853, idx: [4]
# there is a laptop computer sitting on a tvmonitor with a chair
# simlarity (tvmonitor, table): 0.8628, idx: [8]
# there is a laptop computer sitting on a table with a tvmonitor
# simlarity (tvmonitor, chair): 0.8551, idx: [11]
# augemented class:  ['computer', 'table', 'chair']
# ** BLIP prompt: there is a black fire hydrant sitting in a gravel area
# {'fire': [4], 'hydrant': [5], 'area': [10]}
# >>> class name: pottedplant
# there is a black pottedplant hydrant sitting in a gravel area
# simlarity (pottedplant, fire): 0.8173, idx: [4]
# there is a black fire pottedplant sitting in a gravel area
# simlarity (pottedplant, hydrant): 0.7707, idx: [5]
# there is a black fire hydrant sitting in a gravel pottedplant
# simlarity (pottedplant, area): 0.8640, idx: [10]
# augemented class:  ['area']
# ** BLIP prompt: there is a sailboat with a sail that is sailing in the ocean
# {'sailboat': [3], 'sail': [6], 'ocean': [12]}
# >>> class name: boat
# there is a boat with a sail that is sailing in the ocean
# simlarity (boat, sailboat): 0.8985, idx: [3]
# there is a boatboat with a boat that is boating in the ocean
# simlarity (boat, sail): 0.9347, idx: [6]
# there is a sailsail with a sail that is sailing in the boat
# simlarity (boat, ocean): 0.8211, idx: [12]
# augemented class:  ['sailboat', 'sail']
# ** BLIP prompt: there is a yellow and green bird with a yellow beak
# {'bird': [6], 'beak': [10]}
# >>> class name: bird
# there is a yellow and green bird with a yellow bird
# simlarity (bird, beak): 0.8778, idx: [10]
# augemented class:  ['beak']
# ** BLIP prompt: there is a horse that is standing in the woods eating hay
# {'horse': [3], 'wood': [9], 'hay': [11]}
# >>> class name: horse
# there is a horse that is standing in the horses eating hay
# simlarity (horse, wood): 0.7788, idx: [9]
# there is a wood that is standing in the woods eating horse
# simlarity (horse, hay): 0.8207, idx: [11]
# augemented class:  []
# ** BLIP prompt: there is a jet flying in the sky with a blue sky behind it
# {'jet': [3], 'sky': [7, 11], 'blue': [10]}
# >>> class name: aeroplane
# there is a aeroplane flying in the sky with a blue sky behind it
# simlarity (aeroplane, jet): 0.8574, idx: [3]
# there is a jet flying in the aeroplane with a blue aeroplane behind it
# simlarity (aeroplane, sky): 0.8069, idx: [7, 11]
# there is a jet flying in the sky with a aeroplane sky behind it
# simlarity (aeroplane, blue): 0.7845, idx: [10]
# augemented class:  ['jet']
# ** BLIP prompt: motorcycles parked in front of a building with a sign on it
# {'motorcycle': [0], 'front': [3], 'building': [6], 'sign': [9]}
# >>> class name: motorbike
# motorbikes parked in front of a building with a sign on it
# simlarity (motorbike, motorcycle): 0.6210, idx: [0]
# motorcycles parked in motorbike of a building with a sign on it
# simlarity (motorbike, front): 0.7008, idx: [3]
# motorcycles parked in front of a motorbike with a sign on it
# simlarity (motorbike, building): 0.7534, idx: [6]
# motorcycles parked in front of a building with a motorbike on it
# simlarity (motorbike, sign): 0.7775, idx: [9]
# augemented class:  []
# ** BLIP prompt: a close up of a table with a wooden top and a wooden base
# {'table': [5], 'top': [9], 'base': [13]}
# >>> class name: diningtable
# a close up of a diningtable with a wooden top and a wooden base
# simlarity (diningtable, table): 0.8215, idx: [5]
# a close up of a table with a wooden diningtable and a wooden base
# simlarity (diningtable, top): 0.8325, idx: [9]
# a close up of a table with a wooden top and a wooden diningtable
# simlarity (diningtable, base): 0.8236, idx: [13]
# augemented class:  []
# ** BLIP prompt: arafed scooter parked in front of a boarded building
# {'scooter': [1], 'front': [4], 'building': [8]}
# >>> class name: motorbike
# arafed motorbike parked in front of a boarded building
# simlarity (motorbike, scooter): 0.8338, idx: [1]
# arafed scooter parked in motorbike of a boarded building
# simlarity (motorbike, front): 0.9198, idx: [4]
# arafed scooter parked in front of a boarded motorbike
# simlarity (motorbike, building): 0.7730, idx: [8]
# augemented class:  ['front']
# ** BLIP prompt: there are two cats that are laying down together on the couch
# {'cat': [3], 'couch': [11]}
# >>> class name: cat
# there are two cats that are laying down together on the cat
# simlarity (cat, couch): 0.6546, idx: [11]
# augemented class:  []
# ** BLIP prompt: there are three bikes parked next to a building on the street
# {'bike': [3], 'building': [8], 'street': [11]}
# >>> class name: bicycle
# there are three bicycles parked next to a building on the street
# simlarity (bicycle, bike): 0.9508, idx: [3]
# there are three bikes parked next to a bicycle on the street
# simlarity (bicycle, building): 0.8355, idx: [8]
# there are three bikes parked next to a building on the bicycle
# simlarity (bicycle, street): 0.7781, idx: [11]
# augemented class:  ['bike']
# ** BLIP prompt: there is a bike that is sitting on a stand in the living room
# {'bike': [3], 'stand': [9], 'living': [12], 'room': [13]}
# >>> class name: bicycle
# there is a bicycle that is sitting on a stand in the living room
# simlarity (bicycle, bike): 0.9503, idx: [3]
# there is a bike that is sitting on a bicycle in the living room
# simlarity (bicycle, stand): 0.7566, idx: [9]
# there is a bike that is sitting on a stand in the bicycle room
# simlarity (bicycle, living): 0.7349, idx: [12]
# there is a bike that is sitting on a stand in the living bicycle
# simlarity (bicycle, room): 0.6398, idx: [13]
# augemented class:  ['bike']
# >>> class name: sofa
# there is a sofa that is sitting on a stand in the living room
# simlarity (sofa, bike): 0.8075, idx: [3]
# there is a bike that is sitting on a sofa in the living room
# simlarity (sofa, stand): 0.7609, idx: [9]
# there is a bike that is sitting on a stand in the sofa room
# simlarity (sofa, living): 0.8367, idx: [12]
# there is a bike that is sitting on a stand in the living sofa
# simlarity (sofa, room): 0.7294, idx: [13]
# augemented class:  []
# ** BLIP prompt: there is a motorcycle parked on the side of the street
# {'motorcycle': [3], 'side': [7], 'street': [10]}
# >>> class name: motorbike
# there is a motorbike parked on the side of the street
# simlarity (motorbike, motorcycle): 0.8667, idx: [3]
# there is a motorcycle parked on the motorbike of the street
# simlarity (motorbike, side): 0.8062, idx: [7]
# there is a motorcycle parked on the side of the motorbike
# simlarity (motorbike, street): 0.7441, idx: [10]
# augemented class:  ['motorcycle']
# ** BLIP prompt: arafed train on a track near a hill with trees
# {'train': [1], 'track': [4], 'hill': [7], 'tree': [9]}
# >>> class name: train
# arafed train on a train near a hill with trees
# simlarity (train, track): 0.8725, idx: [4]
# arafed track on a track near a train with trees
# simlarity (train, hill): 0.8301, idx: [7]
# arafed track on a track near a hill with trains
# simlarity (train, tree): 0.8469, idx: [9]
# augemented class:  ['track']
# ** BLIP prompt: there is a bottle of beer sitting on a wooden step
# {'bottle': [3], 'beer': [5], 'step': [10]}
# >>> class name: bottle
# there is a bottle of bottle sitting on a wooden step
# simlarity (bottle, beer): 0.8909, idx: [5]
# there is a beer of beer sitting on a wooden bottle
# simlarity (bottle, step): 0.7331, idx: [10]
# augemented class:  ['beer']
# ** BLIP prompt: there is a brown horse standing on a dirt road
# {'horse': [4], 'dirt': [8], 'road': [9]}
# >>> class name: horse
# there is a brown horse standing on a horse road
# simlarity (horse, dirt): 0.8520, idx: [8]
# there is a brown dirt standing on a dirt horse
# simlarity (horse, road): 0.7449, idx: [9]
# augemented class:  ['dirt']
# ** BLIP prompt: horses standing in a field with a baby horse
# {'horse': [0, 8], 'field': [4], 'baby': [7]}
# >>> class name: horse
# horses standing in a horse with a baby horse
# simlarity (horse, field): 0.7948, idx: [4]
# fields standing in a field with a horse field
# simlarity (horse, baby): 0.6591, idx: [7]
# augemented class:  []
# ** BLIP prompt: there is a bench with a planter and a basket of flowers
# {'bench': [3], 'planter': [6], 'basket': [9], 'flower': [11]}
# >>> class name: pottedplant
# there is a pottedplant with a planter and a basket of flowers
# simlarity (pottedplant, bench): 0.7081, idx: [3]
# there is a bench with a pottedplant and a basket of flowers
# simlarity (pottedplant, planter): 0.8444, idx: [6]
# there is a bench with a planter and a pottedplant of flowers
# simlarity (pottedplant, basket): 0.9278, idx: [9]
# there is a bench with a planter and a basket of pottedplants
# simlarity (pottedplant, flower): 0.8877, idx: [11]
# augemented class:  ['basket', 'flower']
# ** BLIP prompt: there are two flamingos standing on the rocks near the water
# {'rock': [7], 'water': [10]}
# >>> class name: bird
# there are two flamingos standing on the birds near the water
# simlarity (bird, rock): 0.8685, idx: [7]
# there are two flamingos standing on the rocks near the bird
# simlarity (bird, water): 0.8185, idx: [10]
# augemented class:  ['rock']
# ** BLIP prompt: there is a white cow with horns standing in a field
# {'cow': [4], 'horn': [6], 'field': [10]}
# >>> class name: cow
# there is a white cow with cows standing in a field
# simlarity (cow, horn): 0.8629, idx: [6]
# there is a white horn with horns standing in a cow
# simlarity (cow, field): 0.8036, idx: [10]
# augemented class:  ['horn']
# ** BLIP prompt: there is a plant that is growing in a pot in the dirt
# {'plant': [3], 'pot': [9], 'dirt': [12]}
# >>> class name: pottedplant
# there is a pottedplant that is growing in a pot in the dirt
# simlarity (pottedplant, plant): 0.7648, idx: [3]
# there is a plant that is growing in a pottedplant in the dirt
# simlarity (pottedplant, pot): 0.8777, idx: [9]
# there is a plant that is growing in a pot in the pottedplant
# simlarity (pottedplant, dirt): 0.7003, idx: [12]
# augemented class:  ['pot']
# ** BLIP prompt: arafed baby sitting on the floor with a string of lights
# {'baby': [1], 'floor': [5], 'string': [8], 'light': [10]}
# >>> class name: person
# arafed person sitting on the floor with a string of lights
# simlarity (person, baby): 0.9371, idx: [1]
# arafed baby sitting on the person with a string of lights
# simlarity (person, floor): 0.7920, idx: [5]
# arafed baby sitting on the floor with a person of lights
# simlarity (person, string): 0.8001, idx: [8]
# arafed baby sitting on the floor with a string of persons
# simlarity (person, light): 0.7916, idx: [10]
# augemented class:  ['baby']

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"
# !zip -r VOC2012.zip VOC2012
# !zip -r Cityscape.zip Cityscape
# !zip -r Vaihingen.zip Vaihingen
# !zip -r Kvasir-SEG.zip Kvasir-SEG
from google.colab import files
files.download("VOC2012.zip")
files.download("Cityscape.zip")
files.download("Vaihingen.zip")
files.download("Kvasir-SEG.zip")
